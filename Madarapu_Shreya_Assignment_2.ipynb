# %% [markdown]
# <a href="https://colab.research.google.com/github/shreyamadarapu/INFO_5731/blob/main/Madarapu_Shreya_Assignment_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **INFO5731 Assignment 2**
#
# In this assignment, you will work on gathering text data from an open data source via web scraping or API. Following this, you will need to clean the text data and perform syntactic analysis on the data. Follow the instructions carefully and design well-structured Python programs to address each question.
#
# **Expectations**:
# *   Use the provided .*ipynb* document to write your code & respond to the questions. Avoid generating a new file.
# *   Write complete answers and run all the cells before submission.
# *   Make sure the submission is "clean"; *i.e.*, no unnecessary code cells.
# *   Once finished, allow shared rights from top right corner (*see Canvas for details*).
#
# * **Make sure to submit the cleaned data CSV in the comment section - 10 points**
#
# **Total points**: 100
#
# **Deadline**: Wednesday, at 11:59 PM.
#
# **Late Submission will have a penalty of 10% reduction for each day after the deadline.**

# %% [markdown]
# # Question 1 (40 points)
#
# Write a python program to collect text data from **either of the following sources** and save the data into a **csv file:**
#
# (1) Collect all the customer reviews of a product (you can choose any porduct) on amazon. [atleast 1000 reviews]
#
# (2) Collect the top 1000 User Reviews of a movie recently in 2023 or 2024 (you can choose any movie) from IMDB. [If one movie doesn't have sufficient reviews, collect reviews of atleast 2 or 3 movies]
#
# (3) Collect all the reviews of the top 1000 most popular software from G2 or Capterra.
#
# (4) Collect the **abstracts** of the top 10000 research papers by using the query "machine learning", "data science", "artifical intelligence", or "information extraction" from Semantic Scholar.
#
# (5) Collect all the information of the 904 narrators in the Densho Digital Repository.

# %%
import csv
import requests
import concurrent.futures
from bs4 import BeautifulSoup

# Function to collect user reviews from IMDb
def collect_user_reviews(imdb_url):
    review_data = []
    page_num = 1

    # Loop to collect reviews until 1000 reviews are gathered
    while len(review_data) < 1000:
         #Sending a GET request to IMDb with sorting and filtering parameters
        response = requests.get(f"{imdb_url}?sort=helpfulnessScore&dir=desc&ratingFilter=0&page={page_num}")
        soup = BeautifulSoup(response.text, 'html.parser')
        review_containers = soup.find_all('div', class_='review-container')

        if not review_containers:
            break  # No more reviews available

        # Iterating through each review container to extract review text and rating
        for container in review_containers:
            review_text_element = container.find('div', class_='text show-more__control')
            review_rating_element = container.find('span', class_='rating-other-user-rating')

            # Checking if both review text and rating elements are found
            if review_text_element and review_rating_element:
                review_text = review_text_element.text.strip()
                review_rating = review_rating_element.text.strip()
                review_data.append((review_text, review_rating))  # Appending review data as a tuple

                if len(review_data) >= 1000:
                    break

        page_num += 1

    return review_data[:1000]  # Return up to 1000 reviews

# Main function
def main():
    imdb_urls = [
        'https://www.imdb.com/title/tt1517268/reviews',  # Barbie 2023

    ]

    with open('movie_reviews.csv', 'w', newline='', encoding='utf-8') as csvfile:
        fieldnames = ['Review', 'Rating']
        writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
        writer.writeheader()

        total_reviews_collected = 0
        with concurrent.futures.ThreadPoolExecutor() as executor:
            for imdb_url in imdb_urls:
                print(f"Collecting reviews from: {imdb_url}")
                reviews = executor.submit(collect_user_reviews, imdb_url).result()
                for review, rating in reviews:
                    writer.writerow({'Review': review, 'Rating': rating})
                    total_reviews_collected += 1
                    if total_reviews_collected >= 1000:
                        break
                if total_reviews_collected >= 1000:
                    break

    print("Reviews collected and saved to 'movie_reviews.csv'.")

"""
It utilizes concurrent execution with ThreadPoolExecutor to speed up the process of collecting reviews.
The collect_user_reviews function gathers user reviews by sending HTTP requests to IMDb, parsing the HTML response to extract review text and rating,
and then storing them in a list.
"""

if __name__ == "__main__":
    main()
# Out:
# Collecting reviews from: https://www.imdb.com/title/tt1517268/reviews
# Reviews collected and saved to 'movie_reviews.csv'.

# %% [markdown]
# # Question 2 (30 points)
#
# Write a python program to **clean the text data** you collected in the previous question and save the clean data in a new column in the csv file. The data cleaning steps include: [Code and output is required for each part]
#
# (1) Remove noise, such as special characters and punctuations.
#
# (2) Remove numbers.
#
# (3) Remove stopwords by using the stopwords list.
#
# (4) Lowercase all texts
#
# (5) Stemming.
#
# (6) Lemmatization.

# %%
# Write code for each of the sub parts with proper comments.
# !pip install nltk

import csv
import re
import nltk
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer

# Download NLTK resources
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')

# Function to clean and preprocess text
def clean_text(text):
    # Remove noise: special characters and punctuations
    text = re.sub(r'[^a-zA-Z\s]', '', text)

    # Remove numbers
    text = re.sub(r'\d+', '', text)

    # Tokenize the text
    words = nltk.word_tokenize(text)

    # Remove stopwords
    stop_words = set(stopwords.words('english'))
    text = ' '.join([word for word in text.split() if word.lower() not in stop_words])

    # Lowercase all texts
    text=text.lower()

    # Stemming
    stemmer = PorterStemmer()
    text = ' '.join([stemmer.stem(word) for word in text.split()])

    # Lemmatization
    lemmatizer = WordNetLemmatizer()
    text = ' '.join([lemmatizer.lemmatize(word) for word in text.split()])

    # Join the words back into a string
    clean_text = ' '.join(text)

    return text

# Main function to clean the text data
def clean_text_data(input_csv_file, output_csv_file):
    # Read the input CSV file
    with open(input_csv_file, 'r', encoding='utf-8') as csvfile:
        reader = csv.DictReader(csvfile)
        rows = list(reader)

    # Clean the text data and add a new column for clean text
    for row in rows:
        review = row['Review']
        clean_review = clean_text(review)
        row['Clean_Review'] = clean_review

    # Write the cleaned data to a new CSV file
    with open(output_csv_file, 'w', newline='', encoding='utf-8') as csvfile:
        fieldnames = list(rows[0].keys())
        writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
        writer.writeheader()
        writer.writerows(rows)

    print(f"Cleaned data saved to '{output_csv_file}'.")

if __name__ == "__main__":
    input_csv_file = 'movie_reviews.csv'  # Input CSV file containing the original reviews
    output_csv_file = 'cleaned_movie_reviews.csv'  # Output CSV file to save the cleaned reviews
    clean_text_data(input_csv_file, output_csv_file)
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.8.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2023.12.25)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.66.2)
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# Cleaned data saved to 'cleaned_movie_reviews.csv'.

# %% [markdown]
# # Question 3 (30 points)
#
# Write a python program to **conduct syntax and structure analysis of the clean text** you just saved above. The syntax and structure analysis includes:
#
# (1) **Parts of Speech (POS) Tagging:** Tag Parts of Speech of each word in the text, and calculate the total number of N(oun), V(erb), Adj(ective), Adv(erb), respectively.
#
# (2) **Constituency Parsing and Dependency Parsing:** print out the constituency parsing trees and dependency parsing trees of all the sentences. Using one sentence as an example to explain your understanding about the constituency parsing tree and dependency parsing tree.
#
# (3) **Named Entity Recognition:** Extract all the entities such as person names, organizations, locations, product names, and date from the clean texts, calculate the count of each entity.

# %%
# (1) Parts of Speech (POS) Tagging: Tag Parts of Speech of each word in the text, and calculate the total number of N(oun), V(erb), Adj(ective), Adv(erb), respectively.

import nltk
import pandas as pd
from nltk import pos_tag
from nltk.tokenize import word_tokenize
from collections import Counter

# Download NLTK data
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')

def pos_tagging_and_count(text):
    # Tokenize the text
    words = word_tokenize(text)

    # Perform POS tagging
    pos_tags = pos_tag(words)

    # Count the occurrences of each POS
    pos_counts = Counter(tag[1] for tag in pos_tags)

    return pos_counts

# Read cleaned data
cleaned_df = pd.read_csv('cleaned_movie_reviews.csv')

# Apply POS tagging and count for each row in the 'Clean_Review' column
cleaned_df['pos_counts'] = cleaned_df['Clean_Review'].apply(pos_tagging_and_count)

# Initialize counters for POS tags
noun_count = 0
verb_count = 0
adj_count = 0
adv_count = 0

# Iterate over each row and update POS counts
for pos_count in cleaned_df['pos_counts']:
    noun_count += pos_count.get('NN', 0) + pos_count.get('NNS', 0) + pos_count.get('NNP', 0) + pos_count.get('NNPS', 0)
    verb_count += pos_count.get('VB', 0) + pos_count.get('VBD', 0) + pos_count.get('VBG', 0) + pos_count.get('VBN', 0) + pos_count.get('VBP', 0) + pos_count.get('VBZ', 0)
    adj_count += pos_count.get('JJ', 0) + pos_count.get('JJR', 0) + pos_count.get('JJS', 0)
    adv_count += pos_count.get('RB', 0) + pos_count.get('RBR', 0) + pos_count.get('RBS', 0)

# Print POS counts
print("Parts of Speech Counts:")
print(f"Noun: {noun_count}")
print(f"Verb: {verb_count}")
print(f"Adjective: {adj_count}")
print(f"Adverb: {adv_count}")
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# Parts of Speech Counts:
# Noun: 65347
# Verb: 17763
# Adjective: 25639
# Adverb: 5578

# %%
#(2) Constituency Parsing and Dependency Parsing: print out the constituency parsing trees and dependency parsing trees of all the sentences. Using one sentence as an example to explain your understanding about the constituency parsing tree and dependency parsing tree.

import spacy
import pandas as pd
from spacy import displacy

# Load the spaCy English language model
nlp = spacy.load('en_core_web_sm')

def parse_sentences(text):
    # Process the text using spaCy
    doc = nlp(text)

    # Get the first sentence in the document
    first_sent = next(doc.sents)

    # Constituency parsing tree (spaCy doesn't directly provide constituency parsing, so using the text for simplicity)
    constituency_tree = [token.text_with_ws for token in first_sent]
    print("Constituency Parsing Tree:")
    print(' '.join(constituency_tree))

    # Dependency parsing tree
    dependency_tree = [(token.text, token.dep_, token.head.text) for token in first_sent]
    print("\nDependency Parsing Tree:")
    for token, dep, head in dependency_tree:
        print(f"{token} ({dep}) --> {head}")

    # Plot dependency graph
    displacy.render(first_sent, style='dep', jupyter=True)

    print("\n")

if __name__ == '__main__':
    # Read cleaned data
    cleaned_df = pd.read_csv('cleaned_movie_reviews.csv')

    # Apply parsing for the first review only
    parse_sentences(cleaned_df['Clean_Review'][0])

    """
    Dependency parsing analyzes sentence structure by:
      Extracting token text, dependency label, and head word for each word.
      Combining them into tuples representing word relationships.
      Printing these tuples to show the sentence's dependency structure.

     """
# Out:
# Constituency Parsing Tree:
# margot  best  she  given  film  disappoint  market  fun  quirki  satir  homag  movi  start  way  end  overdramat  speech  end  clearli  tri  make  audienc  feel  someth  left  everyon  feel  confus  say  i m  crotcheti  old  man
#
# Dependency Parsing Tree:
# margot (advmod) --> best
# best (advmod) --> given
# she (nsubj) --> given
# given (ROOT) --> given
# film (compound) --> satir
# disappoint (compound) --> market
# market (compound) --> fun
# fun (compound) --> satir
# quirki (compound) --> satir
# satir (compound) --> movi
# homag (compound) --> movi
# movi (nsubj) --> start
# start (dobj) --> given
# way (advmod) --> start
# end (conj) --> given
# overdramat (compound) --> speech
# speech (nsubj) --> end
# end (nsubj) --> make
# clearli (compound) --> tri
# tri (nsubj) --> make
# make (ccomp) --> end
# audienc (nsubj) --> feel
# feel (ccomp) --> make
# someth (advmod) --> left
# left (amod) --> everyon
# everyon (nsubj) --> feel
# feel (ccomp) --> feel
# confus (nsubj) --> say
# say (ccomp) --> feel
# i (nsubj) --> m
# m (ccomp) --> say
# crotcheti (npadvmod) --> old
# old (amod) --> man
# man (dobj) --> given
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="96902fb4ce0143abb2ef72f216a5d09d-0" class="displacy" width="6000" height="662.0" direction="ltr" style="max-width: none; height: 662.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">margot</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">best</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">she</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">given</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">film</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">disappoint</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">market</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1275">fun</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">quirki</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1625">satir</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1800">homag</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1975">movi</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">start</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2325">way</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2500">end</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2675">overdramat</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2850">speech</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3025">end</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3200">clearli</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3375">tri</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3550">make</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3725">audienc</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3725">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3900">feel</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3900">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="4075">someth</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4075">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="4250">left</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="4425">everyon</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4425">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="4600">feel</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4600">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="4775">confus</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4775">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="4950">say</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4950">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="5125">i</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5125">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="5300">m</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="c

# %%
#(3) Named Entity Recognition: Extract all the entities such as person names, organizations, locations, product names, and date from the clean texts, calculate the count of each entity.

#Here's the Python code to conduct Named Entity Recognition:

import spacy
from collections import Counter
import pandas as pd

# Load the spaCy English language model
nlp = spacy.load('en_core_web_sm')

def extract_entities(text):
    # Process the text using spaCy
    doc = nlp(text)

    # Extract named entities and calculate the count of each entity type
    entity_counts = Counter([(ent.text, ent.label_) for ent in doc.ents])

    return entity_counts

if __name__ == '__main__':
    # Read cleaned data
    cleaned_df = pd.read_csv('cleaned_movie_reviews.csv')

    # Apply NER for each review
    cleaned_df['entity_counts'] = cleaned_df['Clean_Review'].apply(extract_entities)

    # Print the count of each entity type for each review
    for i, entity_count in enumerate(cleaned_df['entity_counts']):
        print(f"Entities for Review {i + 1}:")
        for entity, count in entity_count.items():
            print(f"{entity}: {count}")
        print("\n")
# Out:
# Streaming output truncated to the last 5000 lines.
# ('shullivan', 'PERSON'): 1
# ('first', 'ORDINAL'): 1
# ('third', 'ORDINAL'): 1
# ('variou ken agre', 'PERSON'): 1
# ('ken barbi', 'PERSON'): 1
# ('deliveri produc', 'PERSON'): 1
# ('ryan gosl ken doll', 'PERSON'): 1
# ('eight', 'CARDINAL'): 1
# ('vaniti', 'GPE'): 1
# ('ryan gosl', 'PERSON'): 1
# ('chang world advanc femin barbi', 'ORG'): 1
# ('ken dollsal', 'PERSON'): 1
# ('today', 'DATE'): 1
#
#
# Entities for Review 437:
# ('funni icon', 'ORG'): 1
# ('kinda', 'PERSON'): 1
# ('half', 'CARDINAL'): 1
#
#
# Entities for Review 438:
# ('overdramat', 'GPE'): 1
# ('crotcheti', 'PERSON'): 1
# ('second', 'ORDINAL'): 1
# ('half', 'CARDINAL'): 1
#
#
# Entities for Review 439:
# ('two', 'CARDINAL'): 1
# ('day', 'DATE'): 1
# ('everi day', 'EVENT'): 1
# ('compani barbi', 'PERSON'): 1
# ('ken ryan gosl', 'PERSON'): 1
# ('barbi fulli dedic conceit', 'ORG'): 1
# ('fulli', 'GPE'): 1
# ('mattel headquart', 'PERSON'): 1
# ('one third', 'CARDINAL'): 1
# ('bush', 'PERSON'): 1
# ('veng film repeatedli', 'PERSON'): 1
# ('blith patronis manner', 'ORG'): 1
# ('experi', 'NORP'): 1
# ('one', 'CARDINAL'): 1
# ('ken', 'PERSON'): 1
# ('bon mot funni', 'PERSON'): 1
# ('hardli', 'GPE'): 1
#
#
# Entities for Review 440:
# ('qualiti', 'PERSON'): 1
# ('middl exposit', 'PERSON'): 1
# ('cleverli funni movi', 'ORG'): 1
# ('first', 'ORDINAL'): 1
# ('half', 'CARDINAL'): 1
#
#
# Entities for Review 441:
# ('barbi brilliantli handl fine craft', 'ORG'): 1
# ('year ago', 'DATE'): 1
# ('experi', 'NORP'): 1
# ('tri convey', 'PERSON'): 1
# ('experi wrap', 'PRODUCT'): 1
# ('two hour', 'TIME'): 1
# ('narr', 'ORG'): 1
# ('issu', 'ORG'): 1
#
#
# Entities for Review 442:
# ('messag movi heavi', 'ORG'): 1
# ('leav ken', 'PERSON'): 1
# ('ken', 'PERSON'): 1
# ('zero', 'CARDINAL'): 1
# ('disarrayth movi', 'ORG'): 1
#
#
# Entities for Review 443:
# ('surpris', 'NORP'): 1
# ('one', 'CARDINAL'): 1
#
#
# Entities for Review 444:
# ('first', 'ORDINAL'): 1
# ('ryan gosl', 'PERSON'): 1
# ('issu', 'ORG'): 1
# ('mani scenesth second', 'PERSON'): 1
# ('third', 'ORDINAL'): 1
# ('terrif', 'PERSON'): 1
# ('hilari', 'NORP'): 1
# ('supris', 'PERSON'): 1
#
#
# Entities for Review 445:
# ('ken barbi', 'PERSON'): 1
# ('beauti donei', 'PERSON'): 1
# ('degrad mani', 'PERSON'): 1
#
#
# Entities for Review 446:
# ('focus polit', 'PERSON'): 1
# ('one', 'CARDINAL'): 5
# ('surpris', 'NORP'): 1
# ('everi watch', 'PERSON'): 1
#
#
# Entities for Review 447:
# ('today', 'DATE'): 1
# ('two hour', 'TIME'): 1
# ('robi fantast', 'ORG'): 1
# ('issu', 'ORG'): 1
# ('past year', 'DATE'): 1
# ('new year ago', 'DATE'): 1
# ('pepsi', 'ORG'): 1
# ('figur sen', 'PERSON'): 1
# ('nuanc howev', 'PERSON'): 1
# ('moreit', 'GPE'): 1
# ('experi', 'NORP'): 1
#
#
# Entities for Review 448:
# ('first', 'ORDINAL'): 2
# ('one', 'CARDINAL'): 2
# ('ryan gosl', 'PERSON'): 1
# ('nicki minaj', 'PERSON'): 1
# ('billi', 'PERSON'): 1
# ('funni', 'ORG'): 1
# ('second', 'ORDINAL'): 1
#
#
# Entities for Review 449:
# ('funni deepli', 'ORG'): 1
#
#
# Entities for Review 450:
# ('year old', 'DATE'): 1
# ('accounta barbi', 'PERSON'): 1
# ('doingth', 'PERSON'): 1
# ('new patriarchybi end movi barbi', 'ORG'): 1
# ('ken barbi', 'PERSON'): 1
# ('funni part', 'ORG'): 1
#
#
# Entities for Review 451:
# ('honestli doubt movi', 'PERSON'): 1
# ('first', 'ORDINAL'): 1
# ('everi singl', 'PERSON'): 1
# ('gosl mostli', 'PERSON'): 1
# ('song beauti stuck head', 'PERSON'): 1
#
#
# Entities for Review 452:
# ('perfectli', 'ORG'): 1
# ('believ ken receiv', 'PERSON'): 1
# ('first', 'ORDINAL'): 1
# ('potenti chang', 'PERSON'): 1
# ('one', 'CARDINAL'): 1
# ('issu', 'ORG'): 1
#
#
# Entities for Review 453:
# ('cinema kubrick refer', 'PERSON'): 1
# ('olden day', 'DATE'): 1
# ('varieti barbi', 'PERSON'): 1
# ('one', 'CARDINAL'): 2
# ('today', 'DATE'): 1
# ('two', 'CARDINAL'): 1
# ('someth ruth', 'PERSON'): 1
# ('sec', 'ORG'): 1
#
#
# Entities for Review 454:
# ('ten', 'CARDINAL'): 1
#
#
# Entities for Review 455:
# ('ken song', 'PERSON'): 1
# ('potenti fulli', 'PERSON'): 1
#
#
# Entities for Review 456:
# ('corni storylin', 'PERSON'): 1
# ('ken ryan gosl', 'PERSON'): 1
# ('funni part', 'ORG'): 1
#
#
# Entities for Review 457:
# ('ryan gosl', 'PERSON'): 1
# ('kent gosl', 'PERSON'): 1
# ('hilari', 'NORP'): 1
# ('funni cool', 'ORG'): 1
# ('el furthermor', 'ORG'): 1
# ('movi divid', 'PERSON'): 1
#
#
# Entities for Review 458:
# ('matur thinker', 'PERSON'): 1
# ('ryan gosl', 'PERSON'): 1
# ('ken spinoff', 'PERSON'): 1
# ('america', 'GPE'): 1
# ('simu liu', 'PERSON'): 1
# ('lego movi', 'ORG'): 1
#
#
# Entities for Review 459:
# ('shullivan', 'PERSON'): 1
# ('first', 'ORDINAL'): 1
# ('third', 'ORDINAL'): 1
# ('variou ken agre', 'PERSON'): 1
# ('ken barbi', 'PERSON'): 1
# ('deliveri produc', 'PERSON'): 1
# ('ryan gosl ken doll', 'PERSON'): 1
# ('eight', 'CARDINAL'): 1
# ('vaniti', 'GPE'): 1
# ('ryan gosl', 'PERSON'): 1
# ('chang world advanc femin barbi', 'ORG'): 1
# ('ken dollsal', 'PERSON'): 1
# ('today', 'DATE'): 1
#
#
# Entities for Review 460:
# ('funni icon', 'ORG'): 1
# ('kinda', 'PERSON'): 1
# ('half', 'CARDINAL'): 1
#
#
# Entities for Review 461:
# ('overdramat', 'GPE'): 1
# ('crotcheti', 'PERSON'): 1
# ('second', 'ORDINAL'): 1
# ('half', 'CARDINAL'): 1
#
#
# Entities for Review 462:
# ('two', 'CARDINAL'): 1
# ('day', 'DATE'): 1
# ('everi day', 'EVENT'): 1
# ('compani barbi', 'PERSON'): 1
# ('ken ryan gosl', 'PERSON'): 1
# ('barbi fulli dedic conceit', 'ORG'): 1
# ('fulli', 'GPE'): 1
# ('mattel headquart', 'PERSON'): 1
# ('one third', 'CARDINAL'): 1
# ('bush', 'PERSON'): 1
# ('veng film repeatedli', 'PERSON'): 1
# ('blith patronis manner', 'ORG'): 1
# ('experi', 'NORP'): 1
# ('one', 'CARDINAL'): 1
# ('ken', 'PERSON'): 1
# ('bon mot funni', 'PERSON'): 1
# ('hardli', 'GPE'): 1
#
#
# Entities for Review 463:
# ('qualiti', 'PERSON'): 1
# ('middl exposit', 'PERSON'): 1
# ('cleverli funni movi', 'ORG'): 1
# ('first', 'ORDINAL'): 1
# ('half', 'CARDINAL'): 1
#
#
# Entities for Review 464:
# ('barbi brilliantli handl fine craft', 'ORG'): 1
# ('year ago', 'DATE'): 1
# ('experi', 'NORP'): 1
# ('tri convey', 'PERSON'): 1
# ('experi wrap', 'PRODUCT'): 1
# ('two hour', 'TIME'): 1
# ('narr', 'ORG'): 1
# ('issu', 'ORG'): 1
#
#
# Entities for Review 465:
# ('messag movi heavi', 'ORG'): 1
# ('leav ken', 'PERSON'): 1
# ('ken', 'PERSON'): 1
# ('zero', 'CARDINAL'): 1
# ('disarrayth movi', 'ORG'): 1
#
#
# Entities for Review 466:
# ('surpris', 'NORP'): 1
# ('one', 'CARDINAL'): 1
#
#
# Entities for Review 467:
# ('first', 'ORDINAL'): 1
# ('ryan gosl', 'PERSON'): 1
# ('issu', 'ORG'): 1
# ('mani scenesth second', 'PERSON'): 1
# ('third', 'ORDINAL'): 1
# ('terrif', 'PERSON'): 1
# ('hilari', 'NORP'): 1
# ('supris', 'PERSON'): 1
#
#
# Entities for Review 468:
# ('ken barbi', 'PERSON'): 1
# ('beauti donei', 'PERSON'): 1
# ('degrad mani', 'PERSON'): 1
#
#
# Entities for Review 469:
# ('focus polit', 'PERSON'): 1
# ('one', 'CARDINAL'): 5
# ('surpris', 'NORP'): 1
# ('everi watch', 'PERSON'): 1
#
#
# Entities for Review 470:
# ('today', 'DATE'): 1
# ('two hour', 'TIME'): 1
# ('robi fantast', 'ORG'): 1
# ('issu', 'ORG'): 1
# ('past year', 'DATE'): 1
# ('new year ago', 'DATE'): 1
# ('pepsi', 'ORG'): 1
# ('figur sen', 'PERSON'): 1
# ('nuanc howev', 'PERSON'): 1
# ('moreit', 'GPE'): 1
# ('experi', 'NORP'): 1
#
#
# Entities for Review 471:
# ('first', 'ORDINAL'): 2
# ('one', 'CARDINAL'): 2
# ('ryan gosl', 'PERSON'): 1
# ('nicki minaj', 'PERSON'): 1
# ('billi', 'PERSON'): 1
# ('funni', 'ORG'): 1
# ('second', 'ORDINAL'): 1
#
#
# Entities for Review 472:
# ('funni deepli', 'ORG'): 1
#
#
# Entities for Review 473:
# ('year old', 'DATE'): 1
# ('accounta barbi', 'PERSON'): 1
# ('doingth', 'PERSON'): 1
# ('new patriarchybi end movi barbi', 'ORG'): 1
# ('ken barbi', 'PERSON'): 1
# ('funni part', 'ORG'): 1
#
#
# Entities for Review 474:
# ('honestli doubt movi', 'PERSON'): 1
# ('first', 'ORDINAL'): 1
# ('everi singl', 'PERSON'): 1
# ('gosl mostli', 'PERSON'): 1
# ('song beauti stuck head', 'PERSON'): 1
#
#
# Entities for Review 475:
# ('perfectli', 'ORG'): 1
# ('believ ken receiv', 'PERSON'): 1
# ('first', 'ORDINAL'): 1
# ('potenti chang', 'PERSON'): 1
# ('one', 'CARDINAL'): 1
# ('issu', 'ORG'): 1
#
#
# Entities for Review 476:
# ('cinema kubrick refer', 'PERSON'): 1
# ('olden day', 'DATE'): 1
# ('varieti barbi', 'PERSON'): 1
# ('one', 'CARDINAL'): 2
# ('today', 'DATE'): 1
# ('two', 'CARDINAL'): 1
# ('someth ruth', 'PERSON'): 1
# ('sec', 'ORG'): 1
#
#
# Entities for Review 477:
# ('ten', 'CARDINAL'): 1
#
#
# Entities for Review 478:
# ('ken song', 'PERSON'): 1
# ('potenti fulli', 'PERSON'): 1
#
#
# Entities for Review 479:
# ('corni storylin', 'PERSON'): 1
# ('ken ryan gosl', 'PERSON'): 1
# ('funni part', 'ORG'): 1
#
#
# Entities for Review 480:
# ('ryan gosl', 'PERSON'): 1
# ('kent gosl', 'PERSON'): 1
# ('hilari', 'NORP'): 1
# ('funni cool', 'ORG'): 1
# ('el furthermor', 'ORG'): 1
# ('movi divid', 'PERSON'): 1
#
#
# Entities for Review 481:
# ('matur thinker', 'PERSON'): 1
# ('ryan gosl', 'PERSON'): 1
# ('ken spinoff', 'PERSON'): 1
# ('america', 'GPE'): 1
# ('simu liu', 'PERSON'): 1
# ('lego movi', 'ORG'): 1
#
#
# Entities for Review 482:
# ('shullivan', 'PERSON'): 1
# ('first', 'ORDINAL'): 1
# ('third', 'ORDINAL'): 1
# ('variou ken agre', 'PERSON'): 1
# ('ken barbi', 'PERSON'): 1
# ('deliveri produc', 'PERSON'): 1
# ('ryan gosl ken doll', 'PERSON'): 1
# ('eight', 'CARDINAL'): 1
# ('vaniti', 'GPE'): 1
# ('ryan gosl', 'PERSON'): 1
# ('chang world advanc femin barbi', 'ORG'): 1
# ('ken dollsal', 'PERSON'): 1
# ('today', 'DATE'): 1
#
#
# Entities for Review 483:
# ('funni icon', 'ORG'): 1
# ('kinda', 'PERSON'): 1
# ('half', 'CARDINAL'): 1
#
#
# Entities for Review 484:
# ('overdramat', 'GPE'): 1
# ('crotcheti', 'PERSON'): 1
# ('second', 'ORDINAL'): 1
# ('half', 'CARDINAL'): 1
#
#
# Entities for Review 485:
# ('two', 'CARDINAL'): 1
# ('day', 'DATE'): 1
# ('everi day', 'EVENT'): 1
# ('compani barbi', 'PERSON'): 1
# ('ken ryan gosl', 'PERSON'): 1
# ('barbi fulli dedic conceit', 'ORG'): 1
# ('fulli', 'GPE'): 1
# ('mattel headquart', 'PERSON'): 1
# ('one third', 'CARDINAL'): 1
# ('bush', 'PERSON'): 1
# ('veng film repeatedli', 'PERSON'): 1
# ('blith patronis manner', 'ORG'): 1
# ('experi', 'NORP'): 1
# ('one', 'CARDINAL'): 1
# ('ken', 'PERSON'): 1
# ('bon mot funni', 'PERSON'): 1
# ('hardli', 'GPE'): 1
#
#
# Entities for Review 486:
# ('qualiti', 'PERSON'): 1
# ('middl exposit', 'PERSON'): 1
# ('cleverli funni movi', 'ORG'): 1
# ('first', 'ORDINAL'): 1
# ('half', 'CARDINAL'): 1
#
#
# Entities for Review 487:
# ('barbi brilliantli handl fine craft', 'ORG'): 1
# ('year ago', 'DATE'): 1
# ('experi', 'NORP'): 1
# ('tri convey', 'PERSON'): 1
# ('experi wrap', 'PRODUCT'): 1
# ('two hour', 'TIME'): 1
# ('narr', 'ORG'): 1
# ('issu', 'ORG'): 1
#
#
# Entities for Review 488:
# ('messag movi heavi', 'ORG'): 1
# ('leav ken', 'PERSON'): 1
# ('ken', 'PERSON'): 1
# ('zero', 'CARDINAL'): 1
# ('disarrayth movi', 'ORG'): 1
#
#
# Entities for Review 489:
# ('surpris', 'NORP'): 1
# ('one', 'CARDINAL'): 1
#
#
# Entities for Review 490:
# ('first', 'ORDINAL'): 1
# ('ryan gosl', 'PERSON'): 1
# ('issu', 'ORG'): 1
# ('mani scenesth second', 'PERSON'): 1
# ('third', 'ORDINAL'): 1
# ('terrif', 'PERSON'): 1
# ('hilari', 'NORP'): 1
# ('supris', 'PERSON'): 1
#
#
# Entities for Review 491:
# ('ken barbi', 'PERSON'): 1
# ('beauti donei', 'PERSON'): 1
# ('degrad mani', 'PERSON'): 1
#
#
# Entities for Review 492:
# ('focus polit', 'PERSON'): 1
# ('one', 'CARDINAL'): 5
# ('surpris', 'NORP'): 1
# ('everi watch', 'PERSON'): 1
#
#
# Entities for Review 493:
# ('today', 'DATE'): 1
# ('two hour', 'TIME'): 1
# ('robi fantast', 'ORG'): 1
# ('issu', 'ORG'): 1
# ('past year', 'DATE'): 1
# ('new year ago', 'DATE'): 1
# ('pepsi', 'ORG'): 1
# ('figur sen', 'PERSON'): 1
# ('nuanc howev', 'PERSON'): 1
# ('moreit', 'GPE'): 1
# ('experi', 'NORP'): 1
#
#
# Entities for Review 494:
# ('first', 'ORDINAL'): 2
# ('one', 'CARDINAL'): 2
# ('ryan gosl', 'PERSON'): 1
# ('nicki minaj', 'PERSON'): 1
# ('billi', 'PERSON'): 1
# ('funni', 'ORG'): 1
# ('second', 'ORDINAL'): 1
#
#
# Entities for Review 495:
# ('funni deepli', 'ORG'): 1
#
#
# Entities for Review 496:
# ('year old', 'DATE'): 1
# ('accounta barbi', 'PERSON'): 1
# ('doingth', 'PERSON'): 1
# ('new patriarchybi end movi barbi', 'ORG'): 1
# ('ken barbi', 'PERSON'): 1
# ('funni part', 'ORG'): 1
#
#
# Entities for Review 497:
# ('honestli doubt movi', 'PERSON'): 1
# ('first', 'ORDINAL'): 1
# ('everi singl', 'PERSON'): 1
# ('gosl mostli', 'PERSON'): 1
# ('song beauti stuck head', 'PERSON'): 1
#
#
# Entities for Review 498:
# ('perfectli', 'ORG'): 1
# ('believ ken receiv', 'PERSON'): 1
# ('first', 'ORDINAL'): 1
# ('potenti chang', 'PERSON'): 1
# ('one', 'CARDINAL'): 1
# ('issu', 'ORG'): 1
#
#
# Entities for Review 499:
# ('cinema kubrick refer', 'PERSON'): 1
# ('olden day', 'DATE'): 1
# ('varieti barbi', 'PERSON'): 1
# ('one', 'CARDINAL'): 2
# ('today', 'DATE'): 1
# ('two', 'CARDINAL'): 1
# ('someth ruth', 'PERSON'): 1
# ('sec', 'ORG'): 1
#
#
# Entities for Review 500:
# ('ten', 'CARDINAL'): 1
#
#
# Entities for Review 501:
# ('ken song', 'PERSON'): 1
# ('potenti fulli', 'PERSON'): 1
#
#
# Entities for Review 502:
# ('corni storylin', 'PERSON'): 1
# ('ken ryan gosl', 'PERSON'): 1
# ('funni part', 'ORG'): 1
#
#
# Entities for Review 503:
# ('ryan gosl', 'PERSON'): 1
# ('kent gosl', 'PERSON'): 1
# ('hilari', 'NORP'): 1
# ('funni cool', 'ORG'): 1
# ('el furthermor', 'ORG'): 1
# ('movi divid', 'PERSON'): 1
#
#
# Entities for Review 504:
# ('matur thinker', 'PERSON'): 1
# ('ryan gosl', 'PERSON'): 1
# ('ken spinoff', 'PERSON'): 1
# ('america', 'GPE'): 1
# ('simu liu', 'PERSON'): 1
# ('lego movi', 'ORG'): 1
#
#
# Entities for Review 505:
# ('shullivan', 'PERSON'): 1
# ('first', 'ORDINAL'): 1
# ('third', 'ORDINAL'): 1
# ('variou ken agre', 'PERSON'): 1
# ('ken barbi', 'PERSON'): 1
# ('deliveri produc', 'PERSON'): 1
# ('ryan gosl ken doll', 'PERSON'): 1
# ('eight', 'CARDINAL'): 1
# ('vaniti', 'GPE'): 1
# ('ryan gosl', 'PERSON'): 1
# ('chang world advanc femin barbi', 'ORG'): 1
# ('ken dollsal', 'PERSON'): 1
# ('today', 'DATE'): 1
#
#
# Entities for Review 506:
# ('funni icon', 'ORG'): 1
# ('kinda', 'PERSON'): 1
# ('half', 'CARDINAL'): 1
#
#
# Entities for Review 507:
# ('overdramat', 'GPE'): 1
# ('crotcheti', 'PERSON'): 1
# ('second', 'ORDINAL'): 1
# ('half', 'CARDINAL'): 1
#
#
# Entities for Review 508:
# ('two', 'CARDINAL'): 1
# ('day', 'DATE'): 1
# ('everi day', 'EVENT'): 1
# ('compani barbi', 'PERSON'): 1
# ('ken ryan gosl', 'PERSON'): 1
# ('barbi fulli dedic conceit', 'ORG'): 1
# ('fulli', 'GPE'): 1
# ('mattel headquart', 'PERSON'): 1
# ('one third', 'CARDINAL'): 1
# ('bush', 'PERSON'): 1
# ('veng film repeatedli', 'PERSON'): 1
# ('blith patronis manner', 'ORG'): 1
# ('experi', 'NORP'): 1
# ('one', 'CARDINAL'): 1
# ('ken', 'PERSON'): 1
# ('bon mot funni', 'PERSON'): 1
# ('hardli', 'GPE'): 1
#
#
# Entities for Review 509:
# ('qualiti', 'PERSON'): 1
# ('middl exposit', 'PERSON'): 1
# ('cleverli funni movi', 'ORG'): 1
# ('first', 'ORDINAL'): 1
# ('half', 'CARDINAL'): 1
#
#
# Entities for Review 510:
# ('barbi brilliantli handl fine craft', 'ORG'): 1
# ('year ago', 'DATE'): 1
# ('experi', 'NORP'): 1
# ('tri convey', 'PERSON'): 1
# ('experi wrap', 'PRODUCT'): 1
# ('two hour', 'TIME'): 1
# ('narr', 'ORG'): 1
# ('issu', 'ORG'): 1
#
#
# Entities for Review 511:
# ('messag movi heavi', 'ORG'): 1
# ('leav ken', 'PERSON'): 1
# ('ken', 'PERSON'): 1
# ('zero', 'CARDINAL'): 1
# ('disarrayth movi', 'ORG'): 1
#
#
# Entities for Review 512:
# ('surpris', 'NORP'): 1
# ('one', 'CARDINAL'): 1
#
#
# Entities for Review 513:
# ('first', 'ORDINAL'): 1
# ('ryan gosl', 'PERSON'): 1
# ('issu', 'ORG'): 1
# ('mani scenesth second', 'PERSON'): 1
# ('third', 'ORDINAL'): 1
# ('terrif', 'PERSON'): 1
# ('hilari', 'NORP'): 1
# ('supris', 'PERSON'): 1
#
#
# Entities for Review 514:
# ('ken barbi', 'PERSON'): 1
# ('beauti donei', 'PERSON'): 1
# ('degrad mani', 'PERSON'): 1
#
#
# Entities for Review 515:
# ('focus polit', 'PERSON'): 1
# ('one', 'CARDINAL'): 5
# ('surpris', 'NORP'): 1
# ('everi watch', 'PERSON'): 1
#
#
# Entities for Review 516:
# ('today', 'DATE'): 1
# ('two hour', 'TIME'): 1
# ('robi fantast', 'ORG'): 1
# ('issu', 'ORG'): 1
# ('past year', 'DATE'): 1
# ('new year ago', 'DATE'): 1
# ('pepsi', 'ORG'): 1
# ('figur sen', 'PERSON'): 1
# ('nuanc howev', 'PERSON'): 1
# ('moreit', 'GPE'): 1
# ('experi', 'NORP'): 1
#
#
# Entities for Review 517:
# ('first', 'ORDINAL'): 2
# ('one', 'CARDINAL'): 2
# ('ryan gosl', 'PERSON'): 1
# ('nicki minaj', 'PERSON'): 1
# ('billi', 'PERSON'): 1
# ('funni', 'ORG'): 1
# ('second', 'ORDINAL'): 1
#
#
# Entities for Review 518:
# ('funni deepli', 'ORG'): 1
#
#
# Entities for Review 519:
# ('year old', 'DATE'): 1
# ('accounta barbi', 'PERSON'): 1
# ('doingth', 'PERSON'): 1
# ('new patriarchybi end movi barbi', 'ORG'): 1
# ('ken barbi', 'PERSON'): 1
# ('funni part', 'ORG'): 1
#
#
# Entities for Review 520:
# ('honestli doubt movi', 'PERSON'): 1
# ('first', 'ORDINAL'): 1
# ('everi singl', 'PERSON'): 1
# ('gosl mostli', 'PERSON'): 1
# ('song beauti stuck head', 'PERSON'): 1
#
#
# Entities for Review 521:
# ('perfectli', 'ORG'): 1
# ('believ ken receiv', 'PERSON'): 1
# ('first', 'ORDINAL'): 1
# ('potenti chang', 'PERSON'): 1
# ('one', 'CARDINAL'): 1
# ('issu', 'ORG'): 1
#
#
# Entities for Review 522:
# ('cinema kubrick refer', 'PERSON'): 1
# ('olden day', 'DATE'): 1
# ('varieti barbi', 'PERSON'): 1
# ('one', 'CARDINAL'): 2
# ('today', 'DATE'): 1
# ('two', 'CARDINAL'): 1
# ('someth ruth', 'PERSON'): 1
# ('sec', 'ORG'): 1
#
#
# Entities for Review 523:
# ('ten', 'CARDINAL'): 1
#
#
# Entities for Review 524:
# ('ken song', 'PERSON'): 1
# ('potenti fulli', 'PERSON'): 1
#
#
# Entities for Review 525:
# ('corni storylin', 'PERSON'): 1
# ('ken ryan gosl', 'PERSON'): 1
# ('funni part', 'ORG'): 1
#
#
# Entities for Review 526:
# ('ryan gosl', 'PERSON'): 1
# ('kent gosl', 'PERSON'): 1
# ('hilari', 'NORP'): 1
# ('funni cool', 'ORG'): 1
# ('el furthermor', 'ORG'): 1
# ('movi divid', 'PERSON'): 1
#
#
# Entities for Review 527:
# ('matur thinker', 'PERSON'): 1
# ('ryan gosl', 'PERSON'): 1
# ('ken spinoff', 'PERSON'): 1
# ('america', 'GPE'): 1
# ('simu liu', 'PERSON'): 1
# ('lego movi', 'ORG'): 1
#
#
# Entities for Review 528:
# ('shullivan', 'PERSON'): 1
# ('first', 'ORDINAL'): 1
# ('third', 'ORDINAL'): 1
# ('variou ken agre', 'PERSON'): 1
# ('ken barbi', 'PERSON'): 1
# ('deliveri produc', 'PERSON'): 1
# ('ryan gosl ken doll', 'PERSON'): 1
# ('eight', 'CARDINAL'): 1
# ('vaniti', 'GPE'): 1
# ('ryan gosl', 'PERSON'): 1
# ('chang world advanc femin barbi', 'ORG'): 1
# ('ken dollsal', 'PERSON'): 1
# ('today', 'DATE'): 1
#
#
# Entities for Review 529:
# ('funni icon', 'ORG'): 1
# ('kinda', 'PERSON'): 1
# ('half', 'CARDINAL'): 1
#
#
# Entities for Review 530:
# ('overdramat', 'GPE'): 1
# ('crotcheti', 'PERSON'): 1
# ('second', 'ORDINAL'): 1
# ('half', 'CARDINAL'): 1
#
#
# Entities for Review 531:
# ('two', 'CARDINAL'): 1
# ('day', 'DATE'): 1
# ('everi day', 'EVENT'): 1
# ('compani barbi', 'PERSON'): 1
# ('ken ryan gosl', 'PERSON'): 1
# ('barbi fulli dedic conceit', 'ORG'): 1
# ('fulli', 'GPE'): 1
# ('mattel headquart', 'PERSON'): 1
# ('one third', 'CARDINAL'): 1
# ('bush', 'PERSON'): 1
# ('veng film repeatedli', 'PERSON'): 1
# ('blith patronis manner', 'ORG'): 1
# ('experi', 'NORP'): 1
# ('one', 'CARDINAL'): 1
# ('ken', 'PERSON'): 1
# ('bon mot funni', 'PERSON'): 1
# ('hardli', 'GPE'): 1
#
#
# Entities for Review 532:
# ('qualiti', 'PERSON'): 1
# ('middl exposit', 'PERSON'): 1
# ('cleverli funni movi', 'ORG'): 1
# ('first', 'ORDINAL'): 1
# ('half', 'CARDINAL'): 1
#
#
# Entities for Review 533:
# ('barbi brilliantli handl fine craft', 'ORG'): 1
# ('year ago', 'DATE'): 1
# ('experi', 'NORP'): 1
# ('tri convey', 'PERSON'): 1
# ('experi wrap', 'PRODUCT'): 1
# ('two hour', 'TIME'): 1
# ('narr', 'ORG'): 1
# ('issu', 'ORG'): 1
#
#
# Entities for Review 534:
# ('messag movi heavi', 'ORG'): 1
# ('leav ken', 'PERSON'): 1
# ('ken', 'PERSON'): 1
# ('zero', 'CARDINAL'): 1
# ('disarrayth movi', 'ORG'): 1
#
#
# Entities for Review 535:
# ('surpris', 'NORP'): 1
# ('one', 'CARDINAL'): 1
#
#
# Entities for Review 536:
# ('first', 'ORDINAL'): 1
# ('ryan gosl', 'PERSON'): 1
# ('issu', 'ORG'): 1
# ('mani scenesth second', 'PERSON'): 1
# ('third', 'ORDINAL'): 1
# ('terrif', 'PERSON'): 1
# ('hilari', 'NORP'): 1
# ('supris', 'PERSON'): 1
#
#
# Entities for Review 537:
# ('ken barbi', 'PERSON'): 1
# ('beauti donei', 'PERSON'): 1
# ('degrad mani', 'PERSON'): 1
#
#
# Entities for Review 538:
# ('focus polit', 'PERSON'): 1
# ('one', 'CARDINAL'): 5
# ('surpris', 'NORP'): 1
# ('everi watch', 'PERSON'): 1
#
#
# Entities for Review 539:
# ('today', 'DATE'): 1
# ('two hour', 'TIME'): 1
# ('robi fantast', 'ORG'): 1
# ('issu', 'ORG'): 1
# ('past year', 'DATE'): 1
# ('new year ago', 'DATE'): 1
# ('pepsi', 'ORG'): 1
# ('figur sen', 'PERSON'): 1
# ('nuanc howev', 'PERSON'): 1
# ('moreit', 'GPE'): 1
# ('experi', 'NORP'): 1
#
#
# Entities for Review 540:
# ('first', 'ORDINAL'): 2
# ('one', 'CARDINAL'): 2
# ('ryan gosl', 'PERSON'): 1
# ('nicki minaj', 'PERSON'): 1
# ('billi', 'PERSON'): 1
# ('funni', 'ORG'): 1
# ('second', 'ORDINAL'): 1
#
#
# Entities for Review 541:
# ('funni deepli', 'ORG'): 1
#
#
# Entities for Review 542:
# ('year old', 'DATE'): 1
# ('accounta barbi', 'PERSON'): 1
# ('doingth', 'PERSON'): 1
# ('new patriarchybi end movi barbi', 'ORG'): 1
# ('ken barbi', 'PERSON'): 1
# ('funni part', 'ORG'): 1
#
#
# Entities for Review 543:
# ('honestli doubt movi', 'PERSON'): 1
# ('first', 'ORDINAL'): 1
# ('everi singl', 'PERSON'): 1
# ('gosl mostli', 'PERSON'): 1
# ('song beauti stuck head', 'PERSON'): 1
#
#
# Entities for Review 544:
# ('perfectli', 'ORG'): 1
# ('believ ken receiv', 'PERSON'): 1
# ('first', 'ORDINAL'): 1
# ('potenti chang', 'PERSON'): 1
# ('one', 'CARDINAL'): 1
# ('issu', 'ORG'): 1
#
#
# Entities for Review 545:
# ('cinema kubrick refer', 'PERSON'): 1
# ('olden day', 'DATE'): 1
# ('varieti barbi', 'PERSON'): 1
# ('one', 'CARDINAL'): 2
# ('today', 'DATE'): 1
# ('two', 'CARDINAL'): 1
# ('someth ruth', 'PERSON'): 1
# ('sec', 'ORG'): 1
#
#
# Entities for Review 546:
# ('ten', 'CARDINAL'): 1
#
#
# Entities for Review 547:
# ('ken song', 'PERSON'): 1
# ('potenti fulli', 'PERSON'): 1
#
#
# Entities for Review 548:
# ('corni storylin', 'PERSON'): 1
# ('ken ryan gosl', 'PERSON'): 1
# ('funni part', 'ORG'): 1
#
#
# Entities for Review 549:
# ('ryan gosl', 'PERSON'): 1
# ('kent gosl', 'PERSON'): 1
# ('hilari', 'NORP'): 1
# ('funni cool', 'ORG'): 1
# ('el furthermor', 'ORG'): 1
# ('movi divid', 'PERSON'): 1
#
#
# Entities for Review 550:
# ('matur thinker', 'PERSON'): 1
# ('ryan gosl', 'PERSON'): 1
# ('ken spinoff', 'PERSON'): 1
# ('america', 'GPE'): 1
# ('simu liu', 'PERSON'): 1
# ('lego movi', 'ORG'): 1
#
#
# Entities for Review 551:
# ('shullivan', 'PERSON'): 1
# ('first', 'ORDINAL'): 1
# ('third', 'ORDINAL'): 1
# ('variou ken agre', 'PERSON'): 1
# ('ken barbi', 'PERSON'): 1
# ('deliveri produc', 'PERSON'): 1
# ('ryan gosl ken doll', 'PERSON'): 1
# ('eight', 'CARDINAL'): 1
# ('vaniti', 'GPE'): 1
# ('ryan gosl', 'PERSON'): 1
# ('chang world advanc femin barbi', 'ORG'): 1
# ('ken dollsal', 'PERSON'): 1
# ('today', 'DATE'): 1
#
#
# Entities for Review 552:
# ('funni icon', 'ORG'): 1
# ('kinda', 'PERSON'): 1
# ('half', 'CARDINAL'): 1
#
#
# Entities for Review 553:
# ('overdramat', 'GPE'): 1
# ('crotcheti', 'PERSON'): 1
# ('second', 'ORDINAL'): 1
# ('half', 'CARDINAL'): 1
#
#
# Entities for Review 554:
# ('two', 'CARDINAL'): 1
# ('day', 'DATE'): 1
# ('everi day', 'EVENT'): 1
# ('compani barbi', 'PERSON'): 1
# ('ken ryan gosl', 'PERSON'): 1
# ('barbi fulli dedic conceit', 'ORG'): 1
# ('fulli', 'GPE'): 1
# ('mattel headquart', 'PERSON'): 1
# ('one third', 'CARDINAL'): 1
# ('bush', 'PERSON'): 1
# ('veng film repeatedli', 'PERSON'): 1
# ('blith patronis manner', 'ORG'): 1
# ('experi', 'NORP'): 1
# ('one', 'CARDINAL'): 1
# ('ken', 'PERSON'): 1
# ('bon mot funni', 'PERSON'): 1
# ('hardli', 'GPE'): 1
#
#
# Entities for Review 555:
# ('qualiti', 'PERSON'): 1
# ('middl exposit', 'PERSON'): 1
# ('cleverli funni movi', 'ORG'): 1
# ('first', 'ORDINAL'): 1
# ('half', 'CARDINAL'): 1
#
#
# Entities for Review 556:
# ('barbi brilliantli handl fine craft', 'ORG'): 1
# ('year ago', 'DATE'): 1
# ('experi', 'NORP'): 1
# ('tri convey', 'PERSON'): 1
# ('experi wrap', 'PRODUCT'): 1
# ('two hour', 'TIME'): 1
# ('narr', 'ORG'): 1
# ('issu', 'ORG'): 1
#
#
# Entities for Review 557:
# ('messag movi heavi', 'ORG'): 1
# ('leav ken', 'PERSON'): 1
# ('ken', 'PERSON'): 1
# ('zero', 'CARDINAL'): 1
# ('disarrayth movi', 'ORG'): 1
#
#
# Entities for Review 558:
# ('surpris', 'NORP'): 1
# ('one', 'CARDINAL'): 1
#
#
# Entities for Review 559:
# ('first', 'ORDINAL'): 1
# ('ryan gosl', 'PERSON'): 1
# ('issu', 'ORG'): 1
# ('mani scenesth second', 'PERSON'): 1
# ('third', 'ORDINAL'): 1
# ('terrif', 'PERSON'): 1
# ('hilari', 'NORP'): 1
# ('supris', 'PERSON'): 1
#
#
# Entities for Review 560:
# ('ken barbi', 'PERSON'): 1
# ('beauti donei', 'PERSON'): 1
# ('degrad mani', 'PERSON'): 1
#
#
# Entities for Review 561:
# ('focus polit', 'PERSON'): 1
# ('one', 'CARDINAL'): 5
# ('surpris', 'NORP'): 1
# ('everi watch', 'PERSON'): 1
#
#
# Entities for Review 562:
# ('today', 'DATE'): 1
# ('two hour', 'TIME'): 1
# ('robi fantast', 'ORG'): 1
# ('issu', 'ORG'): 1
# ('past year', 'DATE'): 1
# ('new year ago', 'DATE'): 1
# ('pepsi', 'ORG'): 1
# ('figur sen', 'PERSON'): 1
# ('nuanc howev', 'PERSON'): 1
# ('moreit', 'GPE'): 1
# ('experi', 'NORP'): 1
#
#
# Entities for Review 563:
# ('first', 'ORDINAL'): 2
# ('one', 'CARDINAL'): 2
# ('ryan gosl', 'PERSON'): 1
# ('nicki minaj', 'PERSON'): 1
# ('billi', 'PERSON'): 1
# ('funni', 'ORG'): 1
# ('second', 'ORDINAL'): 1
#
#
# Entities for Review 564:
# ('funni deepli', 'ORG'): 1
#
#
# Entities for Review 565:
# ('year old', 'DATE'): 1
# ('accounta barbi', 'PERSON'): 1
# ('doingth', 'PERSON'): 1
# ('new patriarchybi end movi barbi', 'ORG'): 1
# ('ken barbi', 'PERSON'): 1
# ('funni part', 'ORG'): 1
#
#
# Entities for Review 566:
# ('honestli doubt movi', 'PERSON'): 1
# ('first', 'ORDINAL'): 1
# ('everi singl', 'PERSON'): 1
# ('gosl mostli', 'PERSON'): 1
# ('song beauti stuck head', 'PERSON'): 1
#
#
# Entities for Review 567:
# ('perfectli', 'ORG'): 1
# ('believ ken receiv', 'PERSON'): 1
# ('first', 'ORDINAL'): 1
# ('potenti chang', 'PERSON'): 1
# ('one', 'CARDINAL'): 1
# ('issu', 'ORG'): 1
#
#
# Entities for Review 568:
# ('cinema kubrick refer', 'PERSON'): 1
# ('olden day', 'DATE'): 1
# ('varieti barbi', 'PERSON'): 1
# ('one', 'CARDINAL'): 2
# ('today', 'DATE'): 1
# ('two', 'CARDINAL'): 1
# ('someth ruth', 'PERSON'): 1
# ('sec', 'ORG'): 1
#
#
# Entities for Review 569:
# ('ten', 'CARDINAL'): 1
#
#
# Entities for Review 570:
# ('ken song', 'PERSON'): 1
# ('potenti fulli', 'PERSON'): 1
#
#
# Entities for Review 571:
# ('corni storylin', 'PERSON'): 1
# ('ken ryan gosl', 'PERSON'): 1
# ('funni part', 'ORG'): 1
#
#
# Entities for Review 572:
# ('ryan gosl', 'PERSON'): 1
# ('kent gosl', 'PERSON'): 1
# ('hilari', 'NORP'): 1
# ('funni cool', 'ORG'): 1
# ('el furthermor', 'ORG'): 1
# ('movi divid', 'PERSON'): 1
#
#
# Entities for Review 573:
# ('matur thinker', 'PERSON'): 1
# ('ryan gosl', 'PERSON'): 1
# ('ken spinoff', 'PERSON'): 1
# ('america', 'GPE'): 1
# ('simu liu', 'PERSON'): 1
# ('lego movi', 'ORG'): 1
#
#
# Entities for Review 574:
# ('shullivan', 'PERSON'): 1
# ('first', 'ORDINAL'): 1
# ('third', 'ORDINAL'): 1
# ('variou ken agre', 'PERSON'): 1
# ('ken barbi', 'PERSON'): 1
# ('deliveri produc', 'PERSON'): 1
# ('ryan gosl ken doll', 'PERSON'): 1
# ('eight', 'CARDINAL'): 1
# ('vaniti', 'GPE'): 1
# ('ryan gosl', 'PERSON'): 1
# ('chang world advanc femin barbi', 'ORG'): 1
# ('ken dollsal', 'PERSON'): 1
# ('today', 'DATE'): 1
#
#
# Entities for Review 575:
# ('funni icon', 'ORG'): 1
# ('kinda', 'PERSON'): 1
# ('half', 'CARDINAL'): 1
#
#
# Entities for Review 576:
# ('overdramat', 'GPE'): 1
# ('crotcheti', 'PERSON'): 1
# ('second', 'ORDINAL'): 1
# ('half', 'CARDINAL'): 1
#
#
# Entities for Review 577:
# ('two', 'CARDINAL'): 1
# ('day', 'DATE'): 1
# ('everi day', 'EVENT'): 1
# ('compani barbi', 'PERSON'): 1
# ('ken ryan gosl', 'PERSON'): 1
# ('barbi fulli dedic conceit', 'ORG'): 1
# ('fulli', 'GPE'): 1
# ('mattel headquart', 'PERSON'): 1
# ('one third', 'CARDINAL'): 1
# ('bush', 'PERSON'): 1
# ('veng film repeatedli', 'PERSON'): 1
# ('blith patronis manner', 'ORG'): 1
# ('experi', 'NORP'): 1
# ('one', 'CARDINAL'): 1
# ('ken', 'PERSON'): 1
# ('bon mot funni', 'PERSON'): 1
# ('hardli', 'GPE'): 1
#
#
# Entities for Review 578:
# ('qualiti', 'PERSON'): 1
# ('middl exposit', 'PERSON'): 1
# ('cleverli funni movi', 'ORG'): 1
# ('first', 'ORDINAL'): 1
# ('half', 'CARDINAL'): 1
#
#
# Entities for Review 579:
# ('barbi brilliantli handl fine craft', 'ORG'): 1
# ('year ago', 'DATE'): 1
# ('experi', 'NORP'): 1
# ('tri convey', 'PERSON'): 1
# ('experi wrap', 'PRODUCT'): 1
# ('two hour', 'TIME'): 1
# ('narr', 'ORG'): 1
# ('issu', 'ORG'): 1
#
#
# Entities for Review 580:
# ('messag movi heavi', 'ORG'): 1
# ('leav ken', 'PERSON'): 1
# ('ken', 'PERSON'): 1
# ('zero', 'CARDINAL'): 1
# ('disarrayth movi', 'ORG'): 1
#
#
# Entities for Review 581:
# ('surpris', 'NORP'): 1
# ('one', 'CARDINAL'): 1
#
#
# Entities for Review 582:
# ('first', 'ORDINAL'): 1
# ('ryan gosl', 'PERSON'): 1
# ('issu', 'ORG'): 1
# ('mani scenesth second', 'PERSON'): 1
# ('third', 'ORDINAL'): 1
# ('terrif', 'PERSON'): 1
# ('hilari', 'NORP'): 1
# ('supris', 'PERSON'): 1
#
#
# Entities for Review 583:
# ('ken barbi', 'PERSON'): 1
# ('beauti donei', 'PERSON'): 1
# ('degrad mani', 'PERSON'): 1
#
#
# Entities for Review 584:
# ('focus polit', 'PERSON'): 1
# ('one', 'CARDINAL'): 5
# ('surpris', 'NORP'): 1
# ('everi watch', 'PERSON'): 1
#
#
# Entities for Review 585:
# ('today', 'DATE'): 1
# ('two hour', 'TIME'): 1
# ('robi fantast', 'ORG'): 1
# ('issu', 'ORG'): 1
# ('past year', 'DATE'): 1
# ('new year ago', 'DATE'): 1
# ('pepsi', 'ORG'): 1
# ('figur sen', 'PERSON'): 1
# ('nuanc howev', 'PERSON'): 1
# ('moreit', 'GPE'): 1
# ('experi', 'NORP'): 1
#
#
# Entities for Review 586:
# ('first', 'ORDINAL'): 2
# ('one', 'CARDINAL'): 2
# ('ryan gosl', 'PERSON'): 1
# ('nicki minaj', 'PERSON'): 1
# ('billi', 'PERSON'): 1
# ('funni', 'ORG'): 1
# ('second', 'ORDINAL'): 1
#
#
# Entities for Review 587:
# ('funni deepli', 'ORG'): 1
#
#
# Entities for Review 588:
# ('year old', 'DATE'): 1
# ('accounta barbi', 'PERSON'): 1
# ('doingth', 'PERSON'): 1
# ('new patriarchybi end movi barbi', 'ORG'): 1
# ('ken barbi', 'PERSON'): 1
# ('funni part', 'ORG'): 1
#
#
# Entities for Review 589:
# ('honestli doubt movi', 'PERSON'): 1
# ('first', 'ORDINAL'): 1
# ('everi singl', 'PERSON'): 1
# ('gosl mostli', 'PERSON'): 1
# ('song beauti stuck head', 'PERSON'): 1
#
#
# Entities for Review 590:
# ('perfectli', 'ORG'): 1
# ('believ ken receiv', 'PERSON'): 1
# ('first', 'ORDINAL'): 1
# ('potenti chang', 'PERSON'): 1
# ('one', 'CARDINAL'): 1
# ('issu', 'ORG'): 1
#
#
# Entities for Review 591:
# ('cinema kubrick refer', 'PERSON'): 1
# ('olden day', 'DATE'): 1
# ('varieti barbi', 'PERSON'): 1
# ('one', 'CARDINAL'): 2
# ('today', 'DATE'): 1
# ('two', 'CARDINAL'): 1
# ('someth ruth', 'PERSON'): 1
# ('sec', 'ORG'): 1
#
#
# Entities for Review 592:
# ('ten', 'CARDINAL'): 1
#
#
# Entities for Review 593:
# ('ken song', 'PERSON'): 1
# ('potenti fulli', 'PERSON'): 1
#
#
# Entities for Review 594:
# ('corni storylin', 'PERSON'): 1
# ('ken ryan gosl', 'PERSON'): 1
# ('funni part', 'ORG'): 1
#
#
# Entities for Review 595:
# ('ryan gosl', 'PERSON'): 1
# ('kent gosl', 'PERSON'): 1
# ('hilari', 'NORP'): 1
# ('funni cool', 'ORG'): 1
# ('el furthermor', 'ORG'): 1
# ('movi divid', 'PERSON'): 1
#
#
# Entities for Review 596:
# ('matur thinker', 'PERSON'): 1
# ('ryan gosl', 'PERSON'): 1
# ('ken spinoff', 'PERSON'): 1
# ('america', 'GPE'): 1
# ('simu liu', 'PERSON'): 1
# ('lego movi', 'ORG'): 1
#
#
# Entities for Review 597:
# ('shullivan', 'PERSON'): 1
# ('first', 'ORDINAL'): 1
# ('third', 'ORDINAL'): 1
# ('variou ken agre', 'PERSON'): 1
# ('ken barbi', 'PERSON'): 1
# ('deliveri produc', 'PERSON'): 1
# ('ryan gosl ken doll', 'PERSON'): 1
# ('eight', 'CARDINAL'): 1
# ('vaniti', 'GPE'): 1
# ('ryan gosl', 'PERSON'): 1
# ('chang world advanc femin barbi', 'ORG'): 1
# ('ken dollsal', 'PERSON'): 1
# ('today', 'DATE'): 1
#
#
# Entities for Review 598:
# ('funni icon', 'ORG'): 1
# ('kinda', 'PERSON'): 1
# ('half', 'CARDINAL'): 1
#
#
# Entities for Review 599:
# ('overdramat', 'GPE'): 1
# ('crotcheti', 'PERSON'): 1
# ('second', 'ORDINAL'): 1
# ('half', 'CARDINAL'): 1
#
#
# Entities for Review 600:
# ('two', 'CARDINAL'): 1
# ('day', 'DATE'): 1
# ('everi day', 'EVENT'): 1
# ('compani barbi', 'PERSON'): 1
# ('ken ryan gosl', 'PERSON'): 1
# ('barbi fulli dedic conceit', 'ORG'): 1
# ('fulli', 'GPE'): 1
# ('mattel headquart', 'PERSON'): 1
# ('one third', 'CARDINAL'): 1
# ('bush', 'PERSON'): 1
# ('veng film repeatedli', 'PERSON'): 1
# ('blith patronis manner', 'ORG'): 1
# ('experi', 'NORP'): 1
# ('one', 'CARDINAL'): 1
# ('ken', 'PERSON'): 1
# ('bon mot funni', 'PERSON'): 1
# ('hardli', 'GPE'): 1
#
#
# Entities for Review 601:
# ('qualiti', 'PERSON'): 1
# ('middl exposit', 'PERSON'): 1
# ('cleverli funni movi', 'ORG'): 1
# ('first', 'ORDINAL'): 1
# ('half', 'CARDINAL'): 1
#
#
# Entities for Review 602:
# ('barbi brilliantli handl fine craft', 'ORG'): 1
# ('year ago', 'DATE'): 1
# ('experi', 'NORP'): 1
# ('tri convey', 'PERSON'): 1
# ('experi wrap', 'PRODUCT'): 1
# ('two hour', 'TIME'): 1
# ('narr', 'ORG'): 1
# ('issu', 'ORG'): 1
#
#
# Entities for Review 603:
# ('messag movi heavi', 'ORG'): 1
# ('leav ken', 'PERSON'): 1
# ('ken', 'PERSON'): 1
# ('zero', 'CARDINAL'): 1
# ('disarrayth movi', 'ORG'): 1
#
#
# Entities for Review 604:
# ('surpris', 'NORP'): 1
# ('one', 'CARDINAL'): 1
#
#
# Entities for Review 605:
# ('first', 'ORDINAL'): 1
# ('ryan gosl', 'PERSON'): 1
# ('issu', 'ORG'): 1
# ('mani scenesth second', 'PERSON'): 1
# ('third', 'ORDINAL'): 1
# ('terrif', 'PERSON'): 1
# ('hilari', 'NORP'): 1
# ('supris', 'PERSON'): 1
#
#
# Entities for Review 606:
# ('ken barbi', 'PERSON'): 1
# ('beauti donei', 'PERSON'): 1
# ('degrad mani', 'PERSON'): 1
#
#
# Entities for Review 607:
# ('focus polit', 'PERSON'): 1
# ('one', 'CARDINAL'): 5
# ('surpris', 'NORP'): 1
# ('everi watch', 'PERSON'): 1
#
#
# Entities for Review 608:
# ('today', 'DATE'): 1
# ('two hour', 'TIME'): 1
# ('robi fantast', 'ORG'): 1
# ('issu', 'ORG'): 1
# ('past year', 'DATE'): 1
# ('new year ago', 'DATE'): 1
# ('pepsi', 'ORG'): 1
# ('figur sen', 'PERSON'): 1
# ('nuanc howev', 'PERSON'): 1
# ('moreit', 'GPE'): 1
# ('experi', 'NORP'): 1
#
#
# Entities for Review 609:
# ('first', 'ORDINAL'): 2
# ('one', 'CARDINAL'): 2
# ('ryan gosl', 'PERSON'): 1
# ('nicki minaj', 'PERSON'): 1
# ('billi', 'PERSON'): 1
# ('funni', 'ORG'): 1
# ('second', 'ORDINAL'): 1
#
#
# Entities for Review 610:
# ('funni deepli', 'ORG'): 1
#
#
# Entities for Review 611:
# ('year old', 'DATE'): 1
# ('accounta barbi', 'PERSON'): 1
# ('doingth', 'PERSON'): 1
# ('new patriarchybi end movi barbi', 'ORG'): 1
# ('ken barbi', 'PERSON'): 1
# ('funni part', 'ORG'): 1
#
#
# Entities for Review 612:
# ('honestli doubt movi', 'PERSON'): 1
# ('first', 'ORDINAL'): 1
# ('everi singl', 'PERSON'): 1
# ('gosl mostli', 'PERSON'): 1
# ('song beauti stuck head', 'PERSON'): 1
#
#
# Entities for Review 613:
# ('perfectli', 'ORG'): 1
# ('believ ken receiv', 'PERSON'): 1
# ('first', 'ORDINAL'): 1
# ('potenti chang', 'PERSON'): 1
# ('one', 'CARDINAL'): 1
# ('issu', 'ORG'): 1
#
#
# Entities for Review 614:
# ('cinema kubrick refer', 'PERSON'): 1
# ('olden day', 'DATE'): 1
# ('varieti barbi', 'PERSON'): 1
# ('one', 'CARDINAL'): 2
# ('today', 'DATE'): 1
# ('two', 'CARDINAL'): 1
# ('someth ruth', 'PERSON'): 1
# ('sec', 'ORG'): 1
#
#
# Entities for Review 615:
# ('ten', 'CARDINAL'): 1
#
#
# Entities for Review 616:
# ('ken song', 'PERSON'): 1
# ('potenti fulli', 'PERSON'): 1
#
#
# Entities for Review 617:
# ('corni storylin', 'PERSON'): 1
# ('ken ryan gosl', 'PERSON'): 1
# ('funni part', 'ORG'): 1
#
#
# Entities for Review 618:
# ('ryan gosl', 'PERSON'): 1
# ('kent gosl', 'PERSON'): 1
# ('hilari', 'NORP'): 1
# ('funni cool', 'ORG'): 1
# ('el furthermor', 'ORG'): 1
# ('movi divid', 'PERSON'): 1
#
#
# Entities for Review 619:
# ('matur thinker', 'PERSON'): 1
# ('ryan gosl', 'PERSON'): 1
# ('ken spinoff', 'PERSON'): 1
# ('america', 'GPE'): 1
# ('simu liu', 'PERSON'): 1
# ('lego movi', 'ORG'): 1
#
#
# Entities for Review 620:
# ('shullivan', 'PERSON'): 1
# ('first', 'ORDINAL'): 1
# ('third', 'ORDINAL'): 1
# ('variou ken agre', 'PERSON'): 1
# ('ken barbi', 'PERSON'): 1
# ('deliveri produc', 'PERSON'): 1
# ('ryan gosl ken doll', 'PERSON'): 1
# ('eight', 'CARDINAL'): 1
# ('vaniti', 'GPE'): 1
# ('ryan gosl', 'PERSON'): 1
# ('chang world advanc femin barbi', 'ORG'): 1
# ('ken dollsal', 'PERSON'): 1
# ('today', 'DATE'): 1
#
#
# Entities for Review 621:
# ('funni icon', 'ORG'): 1
# ('kinda', 'PERSON'): 1
# ('half', 'CARDINAL'): 1
#
#
# Entities for Review 622:
# ('overdramat', 'GPE'): 1
# ('crotcheti', 'PERSON'): 1
# ('second', 'ORDINAL'): 1
# ('half', 'CARDINAL'): 1
#
#
# Entities for Review 623:
# ('two', 'CARDINAL'): 1
# ('day', 'DATE'): 1
# ('everi day', 'EVENT'): 1
# ('compani barbi', 'PERSON'): 1
# ('ken ryan gosl', 'PERSON'): 1
# ('barbi fulli dedic conceit', 'ORG'): 1
# ('fulli', 'GPE'): 1
# ('mattel headquart', 'PERSON'): 1
# ('one third', 'CARDINAL'): 1
# ('bush', 'PERSON'): 1
# ('veng film repeatedli', 'PERSON'): 1
# ('blith patronis manner', 'ORG'): 1
# ('experi', 'NORP'): 1
# ('one', 'CARDINAL'): 1
# ('ken', 'PERSON'): 1
# ('bon mot funni', 'PERSON'): 1
# ('hardli', 'GPE'): 1
#
#
# Entities for Review 624:
# ('qualiti', 'PERSON'): 1
# ('middl exposit', 'PERSON'): 1
# ('cleverli funni movi', 'ORG'): 1
# ('first', 'ORDINAL'): 1
# ('half', 'CARDINAL'): 1
#
#
# Entities for Review 625:
# ('barbi brilliantli handl fine craft', 'ORG'): 1
# ('year ago', 'DATE'): 1
# ('experi', 'NORP'): 1
# ('tri convey', 'PERSON'): 1
# ('experi wrap', 'PRODUCT'): 1
# ('two hour', 'TIME'): 1
# ('narr', 'ORG'): 1
# ('issu', 'ORG'): 1
#
#
# Entities for Review 626:
# ('messag movi heavi', 'ORG'): 1
# ('leav ken', 'PERSON'): 1
# ('ken', 'PERSON'): 1
# ('zero', 'CARDINAL'): 1
# ('disarrayth movi', 'ORG'): 1
#
#
# Entities for Review 627:
# ('surpris', 'NORP'): 1
# ('one', 'CARDINAL'): 1
#
#
# Entities for Review 628:
# ('first', 'ORDINAL'): 1
# ('ryan gosl', 'PERSON'): 1
# ('issu', 'ORG'): 1
# ('mani scenesth second', 'PERSON'): 1
# ('third', 'ORDINAL'): 1
# ('terrif', 'PERSON'): 1
# ('hilari', 'NORP'): 1
# ('supris', 'PERSON'): 1
#
#
# Entities for Review 629:
# ('ken barbi', 'PERSON'): 1
# ('beauti donei', 'PERSON'): 1
# ('degrad mani', 'PERSON'): 1
#
#
# Entities for Review 630:
# ('focus polit', 'PERSON'): 1
# ('one', 'CARDINAL'): 5
# ('surpris', 'NORP'): 1
# ('everi watch', 'PERSON'): 1
#
#
# Entities for Review 631:
# ('today', 'DATE'): 1
# ('two hour', 'TIME'): 1
# ('robi fantast', 'ORG'): 1
# ('issu', 'ORG'): 1
# ('past year', 'DATE'): 1
# ('new year ago', 'DATE'): 1
# ('pepsi', 'ORG'): 1
# ('figur sen', 'PERSON'): 1
# ('nuanc howev', 'PERSON'): 1
# ('moreit', 'GPE'): 1
# ('experi', 'NORP'): 1
#
#
# Entities for Review 632:
# ('first', 'ORDINAL'): 2
# ('one', 'CARDINAL'): 2
# ('ryan gosl', 'PERSON'): 1
# ('nicki minaj', 'PERSON'): 1
# ('billi', 'PERSON'): 1
# ('funni', 'ORG'): 1
# ('second', 'ORDINAL'): 1
#
#
# Entities for Review 633:
# ('funni deepli', 'ORG'): 1
#
#
# Entities for Review 634:
# ('year old', 'DATE'): 1
# ('accounta barbi', 'PERSON'): 1
# ('doingth', 'PERSON'): 1
# ('new patriarchybi end movi barbi', 'ORG'): 1
# ('ken barbi', 'PERSON'): 1
# ('funni part', 'ORG'): 1
#
#
# Entities for Review 635:
# ('honestli doubt movi', 'PERSON'): 1
# ('first', 'ORDINAL'): 1
# ('everi singl', 'PERSON'): 1
# ('gosl mostli', 'PERSON'): 1
# ('song beauti stuck head', 'PERSON'): 1
#
#
# Entities for Review 636:
# ('perfectli', 'ORG'): 1
# ('believ ken receiv', 'PERSON'): 1
# ('first', 'ORDINAL'): 1
# ('potenti chang', 'PERSON'): 1
# ('one', 'CARDINAL'): 1
# ('issu', 'ORG'): 1
#
#
# Entities for Review 637:
# ('cinema kubrick refer', 'PERSON'): 1
# ('olden day', 'DATE'): 1
# ('varieti barbi', 'PERSON'): 1
# ('one', 'CARDINAL'): 2
# ('today', 'DATE'): 1
# ('two', 'CARDINAL'): 1
# ('someth ruth', 'PERSON'): 1
# ('sec', 'ORG'): 1
#
#
# Entities for Review 638:
# ('ten', 'CARDINAL'): 1
#
#
# Entities for Review 639:
# ('ken song', 'PERSON'): 1
# ('potenti fulli', 'PERSON'): 1
#
#
# Entities for Review 640:
# ('corni storylin', 'PERSON'): 1
# ('ken ryan gosl', 'PERSON'): 1
# ('funni part', 'ORG'): 1
#
#
# Entities for Review 641:
# ('ryan gosl', 'PERSON'): 1
# ('kent gosl', 'PERSON'): 1
# ('hilari', 'NORP'): 1
# ('funni cool', 'ORG'): 1
# ('el furthermor', 'ORG'): 1
# ('movi divid', 'PERSON'): 1
#
#
# Entities for Review 642:
# ('matur thinker', 'PERSON'): 1
# ('ryan gosl', 'PERSON'): 1
# ('ken spinoff', 'PERSON'): 1
# ('america', 'GPE'): 1
# ('simu liu', 'PERSON'): 1
# ('lego movi', 'ORG'): 1
#
#
# Entities for Review 643:
# ('shullivan', 'PERSON'): 1
# ('first', 'ORDINAL'): 1
# ('third', 'ORDINAL'): 1
# ('variou ken agre', 'PERSON'): 1
# ('ken barbi', 'PERSON'): 1
# ('deliveri produc', 'PERSON'): 1
# ('ryan gosl ken doll', 'PERSON'): 1
# ('eight', 'CARDINAL'): 1
# ('vaniti', 'GPE'): 1
# ('ryan gosl', 'PERSON'): 1
# ('chang world advanc femin barbi', 'ORG'): 1
# ('ken dollsal', 'PERSON'): 1
# ('today', 'DATE'): 1
#
#
# Entities for Review 644:
# ('funni icon', 'ORG'): 1
# ('kinda', 'PERSON'): 1
# ('half', 'CARDINAL'): 1
#
#
# Entities for Review 645:
# ('overdramat', 'GPE'): 1
# ('crotcheti', 'PERSON'): 1
# ('second', 'ORDINAL'): 1
# ('half', 'CARDINAL'): 1
#
#
# Entities for Review 646:
# ('two', 'CARDINAL'): 1
# ('day', 'DATE'): 1
# ('everi day', 'EVENT'): 1
# ('compani barbi', 'PERSON'): 1
# ('ken ryan gosl', 'PERSON'): 1
# ('barbi fulli dedic conceit', 'ORG'): 1
# ('fulli', 'GPE'): 1
# ('mattel headquart', 'PERSON'): 1
# ('one third', 'CARDINAL'): 1
# ('bush', 'PERSON'): 1
# ('veng film repeatedli', 'PERSON'): 1
# ('blith patronis manner', 'ORG'): 1
# ('experi', 'NORP'): 1
# ('one', 'CARDINAL'): 1
# ('ken', 'PERSON'): 1
# ('bon mot funni', 'PERSON'): 1
# ('hardli', 'GPE'): 1
#
#
# Entities for Review 647:
# ('qualiti', 'PERSON'): 1
# ('middl exposit', 'PERSON'): 1
# ('cleverli funni movi', 'ORG'): 1
# ('first', 'ORDINAL'): 1
# ('half', 'CARDINAL'): 1
#
#
# Entities for Review 648:
# ('barbi brilliantli handl fine craft', 'ORG'): 1
# ('year ago', 'DATE'): 1
# ('experi', 'NORP'): 1
# ('tri convey', 'PERSON'): 1
# ('experi wrap', 'PRODUCT'): 1
# ('two hour', 'TIME'): 1
# ('narr', 'ORG'): 1
# ('issu', 'ORG'): 1
#
#
# Entities for Review 649:
# ('messag movi heavi', 'ORG'): 1
# ('leav ken', 'PERSON'): 1
# ('ken', 'PERSON'): 1
# ('zero', 'CARDINAL'): 1
# ('disarrayth movi', 'ORG'): 1
#
#
# Entities for Review 650:
# ('surpris', 'NORP'): 1
# ('one', 'CARDINAL'): 1
#
#
# Entities for Review 651:
# ('first', 'ORDINAL'): 1
# ('ryan gosl', 'PERSON'): 1
# ('issu', 'ORG'): 1
# ('mani scenesth second', 'PERSON'): 1
# ('third', 'ORDINAL'): 1
# ('terrif', 'PERSON'): 1
# ('hilari', 'NORP'): 1
# ('supris', 'PERSON'): 1
#
#
# Entities for Review 652:
# ('ken barbi', 'PERSON'): 1
# ('beauti donei', 'PERSON'): 1
# ('degrad mani', 'PERSON'): 1
#
#
# Entities for Review 653:
# ('focus polit', 'PERSON'): 1
# ('one', 'CARDINAL'): 5
# ('surpris', 'NORP'): 1
# ('everi watch', 'PERSON'): 1
#
#
# Entities for Review 654:
# ('today', 'DATE'): 1
# ('two hour', 'TIME'): 1
# ('robi fantast', 'ORG'): 1
# ('issu', 'ORG'): 1
# ('past year', 'DATE'): 1
# ('new year ago', 'DATE'): 1
# ('pepsi', 'ORG'): 1
# ('figur sen', 'PERSON'): 1
# ('nuanc howev', 'PERSON'): 1
# ('moreit', 'GPE'): 1
# ('experi', 'NORP'): 1
#
#
# Entities for Review 655:
# ('first', 'ORDINAL'): 2
# ('one', 'CARDINAL'): 2
# ('ryan gosl', 'PERSON'): 1
# ('nicki minaj', 'PERSON'): 1
# ('billi', 'PERSON'): 1
# ('funni', 'ORG'): 1
# ('second', 'ORDINAL'): 1
#
#
# Entities for Review 656:
# ('funni deepli', 'ORG'): 1
#
#
# Entities for Review 657:
# ('year old', 'DATE'): 1
# ('accounta barbi', 'PERSON'): 1
# ('doingth', 'PERSON'): 1
# ('new patriarchybi end movi barbi', 'ORG'): 1
# ('ken barbi', 'PERSON'): 1
# ('funni part', 'ORG'): 1
#
#
# Entities for Review 658:
# ('honestli doubt movi', 'PERSON'): 1
# ('first', 'ORDINAL'): 1
# ('everi singl', 'PERSON'): 1
# ('gosl mostli', 'PERSON'): 1
# ('song beauti stuck head', 'PERSON'): 1
#
#
# Entities for Review 659:
# ('perfectli', 'ORG'): 1
# ('believ ken receiv', 'PERSON'): 1
# ('first', 'ORDINAL'): 1
# ('potenti chang', 'PERSON'): 1
# ('one', 'CARDINAL'): 1
# ('issu', 'ORG'): 1
#
#
# Entities for Review 660:
# ('cinema kubrick refer', 'PERSON'): 1
# ('olden day', 'DATE'): 1
# ('varieti barbi', 'PERSON'): 1
# ('one', 'CARDINAL'): 2
# ('today', 'DATE'): 1
# ('two', 'CARDINAL'): 1
# ('someth ruth', 'PERSON'): 1
# ('sec', 'ORG'): 1
#
#
# Entities for Review 661:
# ('ten', 'CARDINAL'): 1
#
#
# Entities for Review 662:
# ('ken song', 'PERSON'): 1
# ('potenti fulli', 'PERSON'): 1
#
#
# Entities for Review 663:
# ('corni storylin', 'PERSON'): 1
# ('ken ryan gosl', 'PERSON'): 1
# ('funni part', 'ORG'): 1
#
#
# Entities for Review 664:
# ('ryan gosl', 'PERSON'): 1
# ('kent gosl', 'PERSON'): 1
# ('hilari', 'NORP'): 1
# ('funni cool', 'ORG'): 1
# ('el furthermor', 'ORG'): 1
# ('movi divid', 'PERSON'): 1
#
#
# Entities for Review 665:
# ('matur thinker', 'PERSON'): 1
# ('ryan gosl', 'PERSON'): 1
# ('ken spinoff', 'PERSON'): 1
# ('america', 'GPE'): 1
# ('simu liu', 'PERSON'): 1
# ('lego movi', 'ORG'): 1
#
#
# Entities for Review 666:
# ('shullivan', 'PERSON'): 1
# ('first', 'ORDINAL'): 1
# ('third', 'ORDINAL'): 1
# ('variou ken agre', 'PERSON'): 1
# ('ken barbi', 'PERSON'): 1
# ('deliveri produc', 'PERSON'): 1
# ('ryan gosl ken doll', 'PERSON'): 1
# ('eight', 'CARDINAL'): 1
# ('vaniti', 'GPE'): 1
# ('ryan gosl', 'PERSON'): 1
# ('chang world advanc femin barbi', 'ORG'): 1
# ('ken dollsal', 'PERSON'): 1
# ('today', 'DATE'): 1
#
#
# Entities for Review 667:
# ('funni icon', 'ORG'): 1
# ('kinda', 'PERSON'): 1
# ('half', 'CARDINAL'): 1
#
#
# Entities for Review 668:
# ('overdramat', 'GPE'): 1
# ('crotcheti', 'PERSON'): 1
# ('second', 'ORDINAL'): 1
# ('half', 'CARDINAL'): 1
#
#
# Entities for Review 669:
# ('two', 'CARDINAL'): 1
# ('day', 'DATE'): 1
# ('everi day', 'EVENT'): 1
# ('compani barbi', 'PERSON'): 1
# ('ken ryan gosl', 'PERSON'): 1
# ('barbi fulli dedic conceit', 'ORG'): 1
# ('fulli', 'GPE'): 1
# ('mattel headquart', 'PERSON'): 1
# ('one third', 'CARDINAL'): 1
# ('bush', 'PERSON'): 1
# ('veng film repeatedli', 'PERSON'): 1
# ('blith patronis manner', 'ORG'): 1
# ('experi', 'NORP'): 1
# ('one', 'CARDINAL'): 1
# ('ken', 'PERSON'): 1
# ('bon mot funni', 'PERSON'): 1
# ('hardli', 'GPE'): 1
#
#
# Entities for Review 670:
# ('qualiti', 'PERSON'): 1
# ('middl exposit', 'PERSON'): 1
# ('cleverli funni movi', 'ORG'): 1
# ('first', 'ORDINAL'): 1
# ('half', 'CARDINAL'): 1
#
#
# Entities for Review 671:
# ('barbi brilliantli handl fine craft', 'ORG'): 1
# ('year ago', 'DATE'): 1
# ('experi', 'NORP'): 1
# ('tri convey', 'PERSON'): 1
# ('experi wrap', 'PRODUCT'): 1
# ('two hour', 'TIME'): 1
# ('narr', 'ORG'): 1
# ('issu', 'ORG'): 1
#
#
# Entities for Review 672:
# ('messag movi heavi', 'ORG'): 1
# ('leav ken', 'PERSON'): 1
# ('ken', 'PERSON'): 1
# ('zero', 'CARDINAL'): 1
# ('disarrayth movi', 'ORG'): 1
#
#
# Entities for Review 673:
# ('surpris', 'NORP'): 1
# ('one', 'CARDINAL'): 1
#
#
# Entities for Review 674:
# ('first', 'ORDINAL'): 1
# ('ryan gosl', 'PERSON'): 1
# ('issu', 'ORG'): 1
# ('mani scenesth second', 'PERSON'): 1
# ('third', 'ORDINAL'): 1
# ('terrif', 'PERSON'): 1
# ('hilari', 'NORP'): 1
# ('supris', 'PERSON'): 1
#
#
# Entities for Review 675:
# ('ken barbi', 'PERSON'): 1
# ('beauti donei', 'PERSON'): 1
# ('degrad mani', 'PERSON'): 1
#
#
# Entities for Review 676:
# ('focus polit', 'PERSON'): 1
# ('one', 'CARDINAL'): 5
# ('surpris', 'NORP'): 1
# ('everi watch', 'PERSON'): 1
#
#
# Entities for Review 677:
# ('today', 'DATE'): 1
# ('two hour', 'TIME'): 1
# ('robi fantast', 'ORG'): 1
# ('issu', 'ORG'): 1
# ('past year', 'DATE'): 1
# ('new year ago', 'DATE'): 1
# ('pepsi', 'ORG'): 1
# ('figur sen', 'PERSON'): 1
# ('nuanc howev', 'PERSON'): 1
# ('moreit', 'GPE'): 1
# ('experi', 'NORP'): 1
#
#
# Entities for Review 678:
# ('first', 'ORDINAL'): 2
# ('one', 'CARDINAL'): 2
# ('ryan gosl', 'PERSON'): 1
# ('nicki minaj', 'PERSON'): 1
# ('billi', 'PERSON'): 1
# ('funni', 'ORG'): 1
# ('second', 'ORDINAL'): 1
#
#
# Entities for Review 679:
# ('funni deepli', 'ORG'): 1
#
#
# Entities for Review 680:
# ('year old', 'DATE'): 1
# ('accounta barbi', 'PERSON'): 1
# ('doingth', 'PERSON'): 1
# ('new patriarchybi end movi barbi', 'ORG'): 1
# ('ken barbi', 'PERSON'): 1
# ('funni part', 'ORG'): 1
#
#
# Entities for Review 681:
# ('honestli doubt movi', 'PERSON'): 1
# ('first', 'ORDINAL'): 1
# ('everi singl', 'PERSON'): 1
# ('gosl mostli', 'PERSON'): 1
# ('song beauti stuck head', 'PERSON'): 1
#
#
# Entities for Review 682:
# ('perfectli', 'ORG'): 1
# ('believ ken receiv', 'PERSON'): 1
# ('first', 'ORDINAL'): 1
# ('potenti chang', 'PERSON'): 1
# ('one', 'CARDINAL'): 1
# ('issu', 'ORG'): 1
#
#
# Entities for Review 683:
# ('cinema kubrick refer', 'PERSON'): 1
# ('olden day', 'DATE'): 1
# ('varieti barbi', 'PERSON'): 1
# ('one', 'CARDINAL'): 2
# ('today', 'DATE'): 1
# ('two', 'CARDINAL'): 1
# ('someth ruth', 'PERSON'): 1
# ('sec', 'ORG'): 1
#
#
# Entities for Review 684:
# ('ten', 'CARDINAL'): 1
#
#
# Entities for Review 685:
# ('ken song', 'PERSON'): 1
# ('potenti fulli', 'PERSON'): 1
#
#
# Entities for Review 686:
# ('corni storylin', 'PERSON'): 1
# ('ken ryan gosl', 'PERSON'): 1
# ('funni part', 'ORG'): 1
#
#
# Entities for Review 687:
# ('ryan gosl', 'PERSON'): 1
# ('kent gosl', 'PERSON'): 1
# ('hilari', 'NORP'): 1
# ('funni cool', 'ORG'): 1
# ('el furthermor', 'ORG'): 1
# ('movi divid', 'PERSON'): 1
#
#
# Entities for Review 688:
# ('matur thinker', 'PERSON'): 1
# ('ryan gosl', 'PERSON'): 1
# ('ken spinoff', 'PERSON'): 1
# ('america', 'GPE'): 1
# ('simu liu', 'PERSON'): 1
# ('lego movi', 'ORG'): 1
#
#
# Entities for Review 689:
# ('shullivan', 'PERSON'): 1
# ('first', 'ORDINAL'): 1
# ('third', 'ORDINAL'): 1
# ('variou ken agre', 'PERSON'): 1
# ('ken barbi', 'PERSON'): 1
# ('deliveri produc', 'PERSON'): 1
# ('ryan gosl ken doll', 'PERSON'): 1
# ('eight', 'CARDINAL'): 1
# ('vaniti', 'GPE'): 1
# ('ryan gosl', 'PERSON'): 1
# ('chang world advanc femin barbi', 'ORG'): 1
# ('ken dollsal', 'PERSON'): 1
# ('today', 'DATE'): 1
#
#
# Entities for Review 690:
# ('funni icon', 'ORG'): 1
# ('kinda', 'PERSON'): 1
# ('half', 'CARDINAL'): 1
#
#
# Entities for Review 691:
# ('overdramat', 'GPE'): 1
# ('crotcheti', 'PERSON'): 1
# ('second', 'ORDINAL'): 1
# ('half', 'CARDINAL'): 1
#
#
# Entities for Review 692:
# ('two', 'CARDINAL'): 1
# ('day', 'DATE'): 1
# ('everi day', 'EVENT'): 1
# ('compani barbi', 'PERSON'): 1
# ('ken ryan gosl', 'PERSON'): 1
# ('barbi fulli dedic conceit', 'ORG'): 1
# ('fulli', 'GPE'): 1
# ('mattel headquart', 'PERSON'): 1
# ('one third', 'CARDINAL'): 1
# ('bush', 'PERSON'): 1
# ('veng film repeatedli', 'PERSON'): 1
# ('blith patronis manner', 'ORG'): 1
# ('experi', 'NORP'): 1
# ('one', 'CARDINAL'): 1
# ('ken', 'PERSON'): 1
# ('bon mot funni', 'PERSON'): 1
# ('hardli', 'GPE'): 1
#
#
# Entities for Review 693:
# ('qualiti', 'PERSON'): 1
# ('middl exposit', 'PERSON'): 1
# ('cleverli funni movi', 'ORG'): 1
# ('first', 'ORDINAL'): 1
# ('half', 'CARDINAL'): 1
#
#
# Entities for Review 694:
# ('barbi brilliantli handl fine craft', 'ORG'): 1
# ('year ago', 'DATE'): 1
# ('experi', 'NORP'): 1
# ('tri convey', 'PERSON'): 1
# ('experi wrap', 'PRODUCT'): 1
# ('two hour', 'TIME'): 1
# ('narr', 'ORG'): 1
# ('issu', 'ORG'): 1
#
#
# Entities for Review 695:
# ('messag movi heavi', 'ORG'): 1
# ('leav ken', 'PERSON'): 1
# ('ken', 'PERSON'): 1
# ('zero', 'CARDINAL'): 1
# ('disarrayth movi', 'ORG'): 1
#
#
# Entities for Review 696:
# ...
# ('someth ruth', 'PERSON'): 1
# ('sec', 'ORG'): 1
#
#
# Entities for Review 914:
# ('ten', 'CARDINAL'): 1
#
#
# Entities for Review 915:
# ('ken song', 'PERSON'): 1
# ('potenti fulli', 'PERSON'): 1
#
#
# Entities for Review 916:
# ('corni storylin', 'PERSON'): 1
# ('ken ryan gosl', 'PERSON'): 1
# ('funni part', 'ORG'): 1
#
#
# Entities for Review 917:
# ('ryan gosl', 'PERSON'): 1
# ('kent gosl', 'PERSON'): 1
# ('hilari', 'NORP'): 1
# ('funni cool', 'ORG'): 1
# ('el furthermor', 'ORG'): 1
# ('movi divid', 'PERSON'): 1
#
#
# Entities for Review 918:
# ('matur thinker', 'PERSON'): 1
# ('ryan gosl', 'PERSON'): 1
# ('ken spinoff', 'PERSON'): 1
# ('america', 'GPE'): 1
# ('simu liu', 'PERSON'): 1
# ('lego movi', 'ORG'): 1
#
#
# Entities for Review 919:
# ('shullivan', 'PERSON'): 1
# ('first', 'ORDINAL'): 1
# ('third', 'ORDINAL'): 1
# ('variou ken agre', 'PERSON'): 1
# ('ken barbi', 'PERSON'): 1
# ('deliveri produc', 'PERSON'): 1
# ('ryan gosl ken doll', 'PERSON'): 1
# ('eight', 'CARDINAL'): 1
# ('vaniti', 'GPE'): 1
# ('ryan gosl', 'PERSON'): 1
# ('chang world advanc femin barbi', 'ORG'): 1
# ('ken dollsal', 'PERSON'): 1
# ('today', 'DATE'): 1
#
#
# Entities for Review 920:
# ('funni icon', 'ORG'): 1
# ('kinda', 'PERSON'): 1
# ('half', 'CARDINAL'): 1
#
#
# Entities for Review 921:
# ('overdramat', 'GPE'): 1
# ('crotcheti', 'PERSON'): 1
# ('second', 'ORDINAL'): 1
# ('half', 'CARDINAL'): 1
#
#
# Entities for Review 922:
# ('two', 'CARDINAL'): 1
# ('day', 'DATE'): 1
# ('everi day', 'EVENT'): 1
# ('compani barbi', 'PERSON'): 1
# ('ken ryan gosl', 'PERSON'): 1
# ('barbi fulli dedic conceit', 'ORG'): 1
# ('fulli', 'GPE'): 1
# ('mattel headquart', 'PERSON'): 1
# ('one third', 'CARDINAL'): 1
# ('bush', 'PERSON'): 1
# ('veng film repeatedli', 'PERSON'): 1
# ('blith patronis manner', 'ORG'): 1
# ('experi', 'NORP'): 1
# ('one', 'CARDINAL'): 1
# ('ken', 'PERSON'): 1
# ('bon mot funni', 'PERSON'): 1
# ('hardli', 'GPE'): 1
#
#
# Entities for Review 923:
# ('qualiti', 'PERSON'): 1
# ('middl exposit', 'PERSON'): 1
# ('cleverli funni movi', 'ORG'): 1
# ('first', 'ORDINAL'): 1
# ('half', 'CARDINAL'): 1
#
#
# Entities for Review 924:
# ('barbi brilliantli handl fine craft', 'ORG'): 1
# ('year ago', 'DATE'): 1
# ('experi', 'NORP'): 1
# ('tri convey', 'PERSON'): 1
# ('experi wrap', 'PRODUCT'): 1
# ('two hour', 'TIME'): 1
# ('narr', 'ORG'): 1
# ('issu', 'ORG'): 1
#
#
# Entities for Review 925:
# ('messag movi heavi', 'ORG'): 1
# ('leav ken', 'PERSON'): 1
# ('ken', 'PERSON'): 1
# ('zero', 'CARDINAL'): 1
# ('disarrayth movi', 'ORG'): 1
#
#
# Entities for Review 926:
# ('surpris', 'NORP'): 1
# ('one', 'CARDINAL'): 1
#
#
# Entities for Review 927:
# ('first', 'ORDINAL'): 1
# ('ryan gosl', 'PERSON'): 1
# ('issu', 'ORG'): 1
# ('mani scenesth second', 'PERSON'): 1
# ('third', 'ORDINAL'): 1
# ('terrif', 'PERSON'): 1
# ('hilari', 'NORP'): 1
# ('supris', 'PERSON'): 1
#
#
# Entities for Review 928:
# ('ken barbi', 'PERSON'): 1
# ('beauti donei', 'PERSON'): 1
# ('degrad mani', 'PERSON'): 1
#
#
# Entities for Review 929:
# ('focus polit', 'PERSON'): 1
# ('one', 'CARDINAL'): 5
# ('surpris', 'NORP'): 1
# ('everi watch', 'PERSON'): 1
#
#
# Entities for Review 930:
# ('today', 'DATE'): 1
# ('two hour', 'TIME'): 1
# ('robi fantast', 'ORG'): 1
# ('issu', 'ORG'): 1
# ('past year', 'DATE'): 1
# ('new year ago', 'DATE'): 1
# ('pepsi', 'ORG'): 1
# ('figur sen', 'PERSON'): 1
# ('nuanc howev', 'PERSON'): 1
# ('moreit', 'GPE'): 1
# ('experi', 'NORP'): 1
#
#
# Entities for Review 931:
# ('first', 'ORDINAL'): 2
# ('one', 'CARDINAL'): 2
# ('ryan gosl', 'PERSON'): 1
# ('nicki minaj', 'PERSON'): 1
# ('billi', 'PERSON'): 1
# ('funni', 'ORG'): 1
# ('second', 'ORDINAL'): 1
#
#
# Entities for Review 932:
# ('funni deepli', 'ORG'): 1
#
#
# Entities for Review 933:
# ('year old', 'DATE'): 1
# ('accounta barbi', 'PERSON'): 1
# ('doingth', 'PERSON'): 1
# ('new patriarchybi end movi barbi', 'ORG'): 1
# ('ken barbi', 'PERSON'): 1
# ('funni part', 'ORG'): 1
#
#
# Entities for Review 934:
# ('honestli doubt movi', 'PERSON'): 1
# ('first', 'ORDINAL'): 1
# ('everi singl', 'PERSON'): 1
# ('gosl mostli', 'PERSON'): 1
# ('song beauti stuck head', 'PERSON'): 1
#
#
# Entities for Review 935:
# ('perfectli', 'ORG'): 1
# ('believ ken receiv', 'PERSON'): 1
# ('first', 'ORDINAL'): 1
# ('potenti chang', 'PERSON'): 1
# ('one', 'CARDINAL'): 1
# ('issu', 'ORG'): 1
#
#
# Entities for Review 936:
# ('cinema kubrick refer', 'PERSON'): 1
# ('olden day', 'DATE'): 1
# ('varieti barbi', 'PERSON'): 1
# ('one', 'CARDINAL'): 2
# ('today', 'DATE'): 1
# ('two', 'CARDINAL'): 1
# ('someth ruth', 'PERSON'): 1
# ('sec', 'ORG'): 1
#
#
# Entities for Review 937:
# ('ten', 'CARDINAL'): 1
#
#
# Entities for Review 938:
# ('ken song', 'PERSON'): 1
# ('potenti fulli', 'PERSON'): 1
#
#
# Entities for Review 939:
# ('corni storylin', 'PERSON'): 1
# ('ken ryan gosl', 'PERSON'): 1
# ('funni part', 'ORG'): 1
#
#
# Entities for Review 940:
# ('ryan gosl', 'PERSON'): 1
# ('kent gosl', 'PERSON'): 1
# ('hilari', 'NORP'): 1
# ('funni cool', 'ORG'): 1
# ('el furthermor', 'ORG'): 1
# ('movi divid', 'PERSON'): 1
#
#
# Entities for Review 941:
# ('matur thinker', 'PERSON'): 1
# ('ryan gosl', 'PERSON'): 1
# ('ken spinoff', 'PERSON'): 1
# ('america', 'GPE'): 1
# ('simu liu', 'PERSON'): 1
# ('lego movi', 'ORG'): 1
#
#
# Entities for Review 942:
# ('shullivan', 'PERSON'): 1
# ('first', 'ORDINAL'): 1
# ('third', 'ORDINAL'): 1
# ('variou ken agre', 'PERSON'): 1
# ('ken barbi', 'PERSON'): 1
# ('deliveri produc', 'PERSON'): 1
# ('ryan gosl ken doll', 'PERSON'): 1
# ('eight', 'CARDINAL'): 1
# ('vaniti', 'GPE'): 1
# ('ryan gosl', 'PERSON'): 1
# ('chang world advanc femin barbi', 'ORG'): 1
# ('ken dollsal', 'PERSON'): 1
# ('today', 'DATE'): 1
#
#
# Entities for Review 943:
# ('funni icon', 'ORG'): 1
# ('kinda', 'PERSON'): 1
# ('half', 'CARDINAL'): 1
#
#
# Entities for Review 944:
# ('overdramat', 'GPE'): 1
# ('crotcheti', 'PERSON'): 1
# ('second', 'ORDINAL'): 1
# ('half', 'CARDINAL'): 1
#
#
# Entities for Review 945:
# ('two', 'CARDINAL'): 1
# ('day', 'DATE'): 1
# ('everi day', 'EVENT'): 1
# ('compani barbi', 'PERSON'): 1
# ('ken ryan gosl', 'PERSON'): 1
# ('barbi fulli dedic conceit', 'ORG'): 1
# ('fulli', 'GPE'): 1
# ('mattel headquart', 'PERSON'): 1
# ('one third', 'CARDINAL'): 1
# ('bush', 'PERSON'): 1
# ('veng film repeatedli', 'PERSON'): 1
# ('blith patronis manner', 'ORG'): 1
# ('experi', 'NORP'): 1
# ('one', 'CARDINAL'): 1
# ('ken', 'PERSON'): 1
# ('bon mot funni', 'PERSON'): 1
# ('hardli', 'GPE'): 1
#
#
# Entities for Review 946:
# ('qualiti', 'PERSON'): 1
# ('middl exposit', 'PERSON'): 1
# ('cleverli funni movi', 'ORG'): 1
# ('first', 'ORDINAL'): 1
# ('half', 'CARDINAL'): 1
#
#
# Entities for Review 947:
# ('barbi brilliantli handl fine craft', 'ORG'): 1
# ('year ago', 'DATE'): 1
# ('experi', 'NORP'): 1
# ('tri convey', 'PERSON'): 1
# ('experi wrap', 'PRODUCT'): 1
# ('two hour', 'TIME'): 1
# ('narr', 'ORG'): 1
# ('issu', 'ORG'): 1
#
#
# Entities for Review 948:
# ('messag movi heavi', 'ORG'): 1
# ('leav ken', 'PERSON'): 1
# ('ken', 'PERSON'): 1
# ('zero', 'CARDINAL'): 1
# ('disarrayth movi', 'ORG'): 1
#
#
# Entities for Review 949:
# ('surpris', 'NORP'): 1
# ('one', 'CARDINAL'): 1
#
#
# Entities for Review 950:
# ('first', 'ORDINAL'): 1
# ('ryan gosl', 'PERSON'): 1
# ('issu', 'ORG'): 1
# ('mani scenesth second', 'PERSON'): 1
# ('third', 'ORDINAL'): 1
# ('terrif', 'PERSON'): 1
# ('hilari', 'NORP'): 1
# ('supris', 'PERSON'): 1
#
#
# Entities for Review 951:
# ('ken barbi', 'PERSON'): 1
# ('beauti donei', 'PERSON'): 1
# ('degrad mani', 'PERSON'): 1
#
#
# Entities for Review 952:
# ('focus polit', 'PERSON'): 1
# ('one', 'CARDINAL'): 5
# ('surpris', 'NORP'): 1
# ('everi watch', 'PERSON'): 1
#
#
# Entities for Review 953:
# ('today', 'DATE'): 1
# ('two hour', 'TIME'): 1
# ('robi fantast', 'ORG'): 1
# ('issu', 'ORG'): 1
# ('past year', 'DATE'): 1
# ('new year ago', 'DATE'): 1
# ('pepsi', 'ORG'): 1
# ('figur sen', 'PERSON'): 1
# ('nuanc howev', 'PERSON'): 1
# ('moreit', 'GPE'): 1
# ('experi', 'NORP'): 1
#
#
# Entities for Review 954:
# ('first', 'ORDINAL'): 2
# ('one', 'CARDINAL'): 2
# ('ryan gosl', 'PERSON'): 1
# ('nicki minaj', 'PERSON'): 1
# ('billi', 'PERSON'): 1
# ('funni', 'ORG'): 1
# ('second', 'ORDINAL'): 1
#
#
# Entities for Review 955:
# ('funni deepli', 'ORG'): 1
#
#
# Entities for Review 956:
# ('year old', 'DATE'): 1
# ('accounta barbi', 'PERSON'): 1
# ('doingth', 'PERSON'): 1
# ('new patriarchybi end movi barbi', 'ORG'): 1
# ('ken barbi', 'PERSON'): 1
# ('funni part', 'ORG'): 1
#
#
# Entities for Review 957:
# ('honestli doubt movi', 'PERSON'): 1
# ('first', 'ORDINAL'): 1
# ('everi singl', 'PERSON'): 1
# ('gosl mostli', 'PERSON'): 1
# ('song beauti stuck head', 'PERSON'): 1
#
#
# Entities for Review 958:
# ('perfectli', 'ORG'): 1
# ('believ ken receiv', 'PERSON'): 1
# ('first', 'ORDINAL'): 1
# ('potenti chang', 'PERSON'): 1
# ('one', 'CARDINAL'): 1
# ('issu', 'ORG'): 1
#
#
# Entities for Review 959:
# ('cinema kubrick refer', 'PERSON'): 1
# ('olden day', 'DATE'): 1
# ('varieti barbi', 'PERSON'): 1
# ('one', 'CARDINAL'): 2
# ('today', 'DATE'): 1
# ('two', 'CARDINAL'): 1
# ('someth ruth', 'PERSON'): 1
# ('sec', 'ORG'): 1
#
#
# Entities for Review 960:
# ('ten', 'CARDINAL'): 1
#
#
# Entities for Review 961:
# ('ken song', 'PERSON'): 1
# ('potenti fulli', 'PERSON'): 1
#
#
# Entities for Review 962:
# ('corni storylin', 'PERSON'): 1
# ('ken ryan gosl', 'PERSON'): 1
# ('funni part', 'ORG'): 1
#
#
# Entities for Review 963:
# ('ryan gosl', 'PERSON'): 1
# ('kent gosl', 'PERSON'): 1
# ('hilari', 'NORP'): 1
# ('funni cool', 'ORG'): 1
# ('el furthermor', 'ORG'): 1
# ('movi divid', 'PERSON'): 1
#
#
# Entities for Review 964:
# ('matur thinker', 'PERSON'): 1
# ('ryan gosl', 'PERSON'): 1
# ('ken spinoff', 'PERSON'): 1
# ('america', 'GPE'): 1
# ('simu liu', 'PERSON'): 1
# ('lego movi', 'ORG'): 1
#
#
# Entities for Review 965:
# ('shullivan', 'PERSON'): 1
# ('first', 'ORDINAL'): 1
# ('third', 'ORDINAL'): 1
# ('variou ken agre', 'PERSON'): 1
# ('ken barbi', 'PERSON'): 1
# ('deliveri produc', 'PERSON'): 1
# ('ryan gosl ken doll', 'PERSON'): 1
# ('eight', 'CARDINAL'): 1
# ('vaniti', 'GPE'): 1
# ('ryan gosl', 'PERSON'): 1
# ('chang world advanc femin barbi', 'ORG'): 1
# ('ken dollsal', 'PERSON'): 1
# ('today', 'DATE'): 1
#
#
# Entities for Review 966:
# ('funni icon', 'ORG'): 1
# ('kinda', 'PERSON'): 1
# ('half', 'CARDINAL'): 1
#
#
# Entities for Review 967:
# ('overdramat', 'GPE'): 1
# ('crotcheti', 'PERSON'): 1
# ('second', 'ORDINAL'): 1
# ('half', 'CARDINAL'): 1
#
#
# Entities for Review 968:
# ('two', 'CARDINAL'): 1
# ('day', 'DATE'): 1
# ('everi day', 'EVENT'): 1
# ('compani barbi', 'PERSON'): 1
# ('ken ryan gosl', 'PERSON'): 1
# ('barbi fulli dedic conceit', 'ORG'): 1
# ('fulli', 'GPE'): 1
# ('mattel headquart', 'PERSON'): 1
# ('one third', 'CARDINAL'): 1
# ('bush', 'PERSON'): 1
# ('veng film repeatedli', 'PERSON'): 1
# ('blith patronis manner', 'ORG'): 1
# ('experi', 'NORP'): 1
# ('one', 'CARDINAL'): 1
# ('ken', 'PERSON'): 1
# ('bon mot funni', 'PERSON'): 1
# ('hardli', 'GPE'): 1
#
#
# Entities for Review 969:
# ('qualiti', 'PERSON'): 1
# ('middl exposit', 'PERSON'): 1
# ('cleverli funni movi', 'ORG'): 1
# ('first', 'ORDINAL'): 1
# ('half', 'CARDINAL'): 1
#
#
# Entities for Review 970:
# ('barbi brilliantli handl fine craft', 'ORG'): 1
# ('year ago', 'DATE'): 1
# ('experi', 'NORP'): 1
# ('tri convey', 'PERSON'): 1
# ('experi wrap', 'PRODUCT'): 1
# ('two hour', 'TIME'): 1
# ('narr', 'ORG'): 1
# ('issu', 'ORG'): 1
#
#
# Entities for Review 971:
# ('messag movi heavi', 'ORG'): 1
# ('leav ken', 'PERSON'): 1
# ('ken', 'PERSON'): 1
# ('zero', 'CARDINAL'): 1
# ('disarrayth movi', 'ORG'): 1
#
#
# Entities for Review 972:
# ('surpris', 'NORP'): 1
# ('one', 'CARDINAL'): 1
#
#
# Entities for Review 973:
# ('first', 'ORDINAL'): 1
# ('ryan gosl', 'PERSON'): 1
# ('issu', 'ORG'): 1
# ('mani scenesth second', 'PERSON'): 1
# ('third', 'ORDINAL'): 1
# ('terrif', 'PERSON'): 1
# ('hilari', 'NORP'): 1
# ('supris', 'PERSON'): 1
#
#
# Entities for Review 974:
# ('ken barbi', 'PERSON'): 1
# ('beauti donei', 'PERSON'): 1
# ('degrad mani', 'PERSON'): 1
#
#
# Entities for Review 975:
# ('focus polit', 'PERSON'): 1
# ('one', 'CARDINAL'): 5
# ('surpris', 'NORP'): 1
# ('everi watch', 'PERSON'): 1
#
#
# Entities for Review 976:
# ('today', 'DATE'): 1
# ('two hour', 'TIME'): 1
# ('robi fantast', 'ORG'): 1
# ('issu', 'ORG'): 1
# ('past year', 'DATE'): 1
# ('new year ago', 'DATE'): 1
# ('pepsi', 'ORG'): 1
# ('figur sen', 'PERSON'): 1
# ('nuanc howev', 'PERSON'): 1
# ('moreit', 'GPE'): 1
# ('experi', 'NORP'): 1
#
#
# Entities for Review 977:
# ('first', 'ORDINAL'): 2
# ('one', 'CARDINAL'): 2
# ('ryan gosl', 'PERSON'): 1
# ('nicki minaj', 'PERSON'): 1
# ('billi', 'PERSON'): 1
# ('funni', 'ORG'): 1
# ('second', 'ORDINAL'): 1
#
#
# Entities for Review 978:
# ('funni deepli', 'ORG'): 1
#
#
# Entities for Review 979:
# ('year old', 'DATE'): 1
# ('accounta barbi', 'PERSON'): 1
# ('doingth', 'PERSON'): 1
# ('new patriarchybi end movi barbi', 'ORG'): 1
# ('ken barbi', 'PERSON'): 1
# ('funni part', 'ORG'): 1
#
#
# Entities for Review 980:
# ('honestli doubt movi', 'PERSON'): 1
# ('first', 'ORDINAL'): 1
# ('everi singl', 'PERSON'): 1
# ('gosl mostli', 'PERSON'): 1
# ('song beauti stuck head', 'PERSON'): 1
#
#
# Entities for Review 981:
# ('perfectli', 'ORG'): 1
# ('believ ken receiv', 'PERSON'): 1
# ('first', 'ORDINAL'): 1
# ('potenti chang', 'PERSON'): 1
# ('one', 'CARDINAL'): 1
# ('issu', 'ORG'): 1
#
#
# Entities for Review 982:
# ('cinema kubrick refer', 'PERSON'): 1
# ('olden day', 'DATE'): 1
# ('varieti barbi', 'PERSON'): 1
# ('one', 'CARDINAL'): 2
# ('today', 'DATE'): 1
# ('two', 'CARDINAL'): 1
# ('someth ruth', 'PERSON'): 1
# ('sec', 'ORG'): 1
#
#
# Entities for Review 983:
# ('ten', 'CARDINAL'): 1
#
#
# Entities for Review 984:
# ('ken song', 'PERSON'): 1
# ('potenti fulli', 'PERSON'): 1
#
#
# Entities for Review 985:
# ('corni storylin', 'PERSON'): 1
# ('ken ryan gosl', 'PERSON'): 1
# ('funni part', 'ORG'): 1
#
#
# Entities for Review 986:
# ('ryan gosl', 'PERSON'): 1
# ('kent gosl', 'PERSON'): 1
# ('hilari', 'NORP'): 1
# ('funni cool', 'ORG'): 1
# ('el furthermor', 'ORG'): 1
# ('movi divid', 'PERSON'): 1
#
#
# Entities for Review 987:
# ('matur thinker', 'PERSON'): 1
# ('ryan gosl', 'PERSON'): 1
# ('ken spinoff', 'PERSON'): 1
# ('america', 'GPE'): 1
# ('simu liu', 'PERSON'): 1
# ('lego movi', 'ORG'): 1
#
#
# Entities for Review 988:
# ('shullivan', 'PERSON'): 1
# ('first', 'ORDINAL'): 1
# ('third', 'ORDINAL'): 1
# ('variou ken agre', 'PERSON'): 1
# ('ken barbi', 'PERSON'): 1
# ('deliveri produc', 'PERSON'): 1
# ('ryan gosl ken doll', 'PERSON'): 1
# ('eight', 'CARDINAL'): 1
# ('vaniti', 'GPE'): 1
# ('ryan gosl', 'PERSON'): 1
# ('chang world advanc femin barbi', 'ORG'): 1
# ('ken dollsal', 'PERSON'): 1
# ('today', 'DATE'): 1
#
#
# Entities for Review 989:
# ('funni icon', 'ORG'): 1
# ('kinda', 'PERSON'): 1
# ('half', 'CARDINAL'): 1
#
#
# Entities for Review 990:
# ('overdramat', 'GPE'): 1
# ('crotcheti', 'PERSON'): 1
# ('second', 'ORDINAL'): 1
# ('half', 'CARDINAL'): 1
#
#
# Entities for Review 991:
# ('two', 'CARDINAL'): 1
# ('day', 'DATE'): 1
# ('everi day', 'EVENT'): 1
# ('compani barbi', 'PERSON'): 1
# ('ken ryan gosl', 'PERSON'): 1
# ('barbi fulli dedic conceit', 'ORG'): 1
# ('fulli', 'GPE'): 1
# ('mattel headquart', 'PERSON'): 1
# ('one third', 'CARDINAL'): 1
# ('bush', 'PERSON'): 1
# ('veng film repeatedli', 'PERSON'): 1
# ('blith patronis manner', 'ORG'): 1
# ('experi', 'NORP'): 1
# ('one', 'CARDINAL'): 1
# ('ken', 'PERSON'): 1
# ('bon mot funni', 'PERSON'): 1
# ('hardli', 'GPE'): 1
#
#
# Entities for Review 992:
# ('qualiti', 'PERSON'): 1
# ('middl exposit', 'PERSON'): 1
# ('cleverli funni movi', 'ORG'): 1
# ('first', 'ORDINAL'): 1
# ('half', 'CARDINAL'): 1
#
#
# Entities for Review 993:
# ('barbi brilliantli handl fine craft', 'ORG'): 1
# ('year ago', 'DATE'): 1
# ('experi', 'NORP'): 1
# ('tri convey', 'PERSON'): 1
# ('experi wrap', 'PRODUCT'): 1
# ('two hour', 'TIME'): 1
# ('narr', 'ORG'): 1
# ('issu', 'ORG'): 1
#
#
# Entities for Review 994:
# ('messag movi heavi', 'ORG'): 1
# ('leav ken', 'PERSON'): 1
# ('ken', 'PERSON'): 1
# ('zero', 'CARDINAL'): 1
# ('disarrayth movi', 'ORG'): 1
#
#
# Entities for Review 995:
# ('surpris', 'NORP'): 1
# ('one', 'CARDINAL'): 1
#
#
# Entities for Review 996:
# ('first', 'ORDINAL'): 1
# ('ryan gosl', 'PERSON'): 1
# ('issu', 'ORG'): 1
# ('mani scenesth second', 'PERSON'): 1
# ('third', 'ORDINAL'): 1
# ('terrif', 'PERSON'): 1
# ('hilari', 'NORP'): 1
# ('supris', 'PERSON'): 1
#
#
# Entities for Review 997:
# ('ken barbi', 'PERSON'): 1
# ('beauti donei', 'PERSON'): 1
# ('degrad mani', 'PERSON'): 1
#
#
# Entities for Review 998:
# ('focus polit', 'PERSON'): 1
# ('one', 'CARDINAL'): 5
# ('surpris', 'NORP'): 1
# ('everi watch', 'PERSON'): 1
#
#
# Entities for Review 999:
# ('today', 'DATE'): 1
# ('two hour', 'TIME'): 1
# ('robi fantast', 'ORG'): 1
# ('issu', 'ORG'): 1
# ('past year', 'DATE'): 1
# ('new year ago', 'DATE'): 1
# ('pepsi', 'ORG'): 1
# ('figur sen', 'PERSON'): 1
# ('nuanc howev', 'PERSON'): 1
# ('moreit', 'GPE'): 1
# ('experi', 'NORP'): 1
#
#
# Entities for Review 1000:
# ('first', 'ORDINAL'): 2
# ('one', 'CARDINAL'): 2
# ('ryan gosl', 'PERSON'): 1
# ('nicki minaj', 'PERSON'): 1
# ('billi', 'PERSON'): 1
# ('funni', 'ORG'): 1
# ('second', 'ORDINAL'): 1

# %% [markdown]
# # Mandatory Question
#
# Provide your thoughts on the assignment. What did you find challenging, and what aspects did you enjoy? Your opinion on the provided time to complete the assignment.

# %%
# Write your response below

"""
Natural language processing (NLP) tasks such as text cleaning, named entity recognition, parsing, and part-of-speech tagging were all part of the assignment. To effectively develop solutions using Python and pertinent libraries like NLTK, spaCy, and pandas, these activities required problem-solving abilities.
The good news is that this job gave me the chance to learn about several NLP topics, such as entity recognition, syntactic and semantic analysis, and text preprocessing. It made it possible to explore and learn how to use other libraries and methodologies, such spaCy and NLTK, to get the results needed.
Working with natural language data presents unique challenges due to its complexity and variability. Tasks such as text cleaning, tokenization, and parsing require careful handling of linguistic nuances and edge cases to ensure accurate and reliable results. But the worst part of this is to make the IMDB url to fetch reviews fom all the pages which ate almost a day by performing trial and error operations, i finally achieved. I felt that the time given was not sufficient because, as a student in last semester , along with this course i also have 3 more and managing all the subjects along with preparation to future job is being difficult these days. I also feel, there should be appropriate guidance from auhthorities if we students are struck in any point which would be very helpful.

"""
# Out:
# ' \nNatural language processing (NLP) tasks such as text cleaning, named entity recognition, parsing, and part-of-speech tagging were all part of the assignment. To effectively develop solutions using Python and pertinent libraries like NLTK, spaCy, and pandas, these activities required problem-solving abilities.\nThe good news is that this job gave me the chance to learn about several NLP topics, such as entity recognition, syntactic and semantic analysis, and text preprocessing. It made it possible to explore and learn how to use other libraries and methodologies, such spaCy and NLTK, to get the results needed.\nWorking with natural language data presents unique challenges due to its complexity and variability. Tasks such as text cleaning, tokenization, and parsing require careful handling of linguistic nuances and edge cases to ensure accurate and reliable results. But the worst part of this is to make the IMDB url to fetch reviews fom all the pages which ate almost a day by performing trial and error operations, i finally achieved. I felt that the time given was not sufficient because, as a student in last semester , along with this course i also have 3 more and managing all the subjects along with preparation to future job is being difficult these days. I also feel, there should be appropriate guidance from auhthorities if we students are struck in any point which would be very helpful.\n\n'
